# %%
# Version 8: table weight rename
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
import time
import glob
g=glob.glob('../input/dataset-2-for-airfare/*.csv')
r2_value=[]
adj_r2_value=[]
RMSE_value=[]
#route_name=[]
Tr=[]
te=[]
mn=[]
max_i_=[]
max_j_=[]
max_k_=[]
max_l_=[]
times=[]

# %%
g
# Out:
# ['../input/dataset-2-for-airfare/train_data.csv']

# %%
#descision tree
from sklearn.tree import DecisionTreeRegressor
def dt(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,o,k):
    start = time.time()
    model = DecisionTreeRegressor().fit(X_train, y_train)
    stop = time.time()
    if o==0:
        predictions = model.predict(X_test)
        mse = mean_squared_error(y_test, predictions)

        print("MSE:", mse)

        rmse = np.sqrt(mse)

        print("RMSE:", rmse)

        r2 = r2_score(y_test, predictions)

        print("R2:", r2)
        ar2=1-(1-r2)*((len(X_test)-1)/(len(X_test)-X_test.shape[1]-1))
        print("Adjusted R2:",ar2)
        Tr.append(1-k)#train
        te.append(k)#test
        r2_value.append(r2)
        adj_r2_value.append(ar2)
        RMSE_value.append(rmse)
        #route_name.append(rt[0])
        mn.append("DecisionTreeRegressor()")
        max_i_.append(0)
        max_j_.append(0)
        max_k_.append(0)
        max_l_.append(0)
        times.append(stop-start)
    return model

# %%
#Random Forest
from sklearn.ensemble import RandomForestRegressor
def rf(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,o,k):
    start = time.time()
    model = RandomForestRegressor().fit(X_train, y_train)
    stop = time.time()
    if o==0:
        predictions = model.predict(X_test)
        mse = mean_squared_error(y_test, predictions)

        print("MSE:", mse)

        rmse = np.sqrt(mse)

        print("RMSE:", rmse)

        r2 = r2_score(y_test, predictions)

        print("R2:", r2)
        ar2=1-(1-r2)*((len(X_test)-1)/(len(X_test)-X_test.shape[1]-1))
        print("Adjusted R2:",ar2)
        Tr.append(1-k)#train
        te.append(k)#test
        r2_value.append(r2)
        adj_r2_value.append(ar2)
        RMSE_value.append(rmse)
        #route_name.append(rt[0])
        mn.append("RandomForestRegressor()")
        max_i_.append(0)
        max_j_.append(0)
        max_k_.append(0)
        max_l_.append(0)
        times.append(stop-start)
    return model

# %%
#Bagging Regressor
from sklearn.ensemble import BaggingRegressor
def br(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,o,k):
    start = time.time()
    model = BaggingRegressor().fit(X_train, y_train)
    stop = time.time()
    if o==0:
        predictions = model.predict(X_test)
        mse = mean_squared_error(y_test, predictions)

        print("MSE:", mse)

        rmse = np.sqrt(mse)

        print("RMSE:", rmse)

        r2 = r2_score(y_test, predictions)

        print("R2:", r2)
        ar2=1-(1-r2)*((len(X_test)-1)/(len(X_test)-X_test.shape[1]-1))
        print("Adjusted R2:",ar2)
        Tr.append(1-k)#train
        te.append(k)#test
        r2_value.append(r2)
        adj_r2_value.append(ar2)
        RMSE_value.append(rmse)
        #route_name.append(rt[0])
        mn.append("BaggingRegressor()")
        max_i_.append(0)
        max_j_.append(0)
        max_k_.append(0)
        max_l_.append(0)
        times.append(stop-start)
    return model

# %%
#
from sklearn.experimental import enable_hist_gradient_boosting 
from sklearn.ensemble import HistGradientBoostingRegressor

def gbr(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,o,k):
    params = {
              #'n_trees_per_iteration_':2,
          #'max_depth': 4,
          #'min_samples_split': 5,
          'learning_rate': 0.3,#[0.1,0.15,0.2,0.175,0.225],
          'loss': 'poisson',#[‘least_squares’, ‘least_absolute_deviation’, ‘poisson’],
            'verbose':2}
    start = time.time()
    model = HistGradientBoostingRegressor(**params).fit(X_train, y_train)
    stop = time.time()
    if o==0:
        predictions = model.predict(X_test)
        mse = mean_squared_error(y_test, predictions)

        print("MSE:", mse)

        rmse = np.sqrt(mse)

        print("RMSE:", rmse)

        r2 = r2_score(y_test, predictions)

        print("R2:", r2)
        ar2=1-(1-r2)*((len(X_test)-1)/(len(X_test)-X_test.shape[1]-1))
        print("Adjusted R2:",ar2)
        Tr.append(1-k)#train
        te.append(k)#test
        r2_value.append(r2)
        adj_r2_value.append(ar2)
        RMSE_value.append(rmse)
        #route_name.append(rt[0])
        mn.append("GradientBoostingRegressor()")
        max_i_.append(0)
        max_j_.append(0)
        max_k_.append(0)
        max_l_.append(0)
        times.append(stop-start)
    return model

# %%
#positive weight DT
def c1(model1,model2,model3,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,tst):
    
    #RF
    #model1=rf(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,1)
    predictions1 = model1.predict(X_test)
    #DT
    #model2=dt(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,1) 
    predictions2 = model2.predict(X_test)
    #BR
    #model3=br(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,1)
    predictions3 = model3.predict(X_test)
    
    
    max_r2=0
    mi=0
    mj=0
    mk=0
    for i in range(0,101):
        for j in range(0,101):
            for k in range(0,101):
                if((i+j+k)==100):
                    #print(i," ",j," ",k)
                    pred=(i/100)*predictions1+(j/100)*predictions2+(k/100)*predictions3
                    r2 = r2_score(y_test, pred)
                    if(r2>max_r2):
                        max_r2=r2
                        mi=i
                        mj=j
                        mk=k
    
    
    predictions = (mi/100)*predictions1+(mj/100)*predictions2+(mk/100)*predictions3
    mse = mean_squared_error(y_test, predictions)

    print("MSE:", mse)

    rmse = np.sqrt(mse)

    print("RMSE:", rmse)

    r2 = r2_score(y_test, predictions)

    print("R2:", r2)
    ar2=1-(1-r2)*((len(X_test)-1)/(len(X_test)-X_test.shape[1]-1))
    print("Adjusted R2:",ar2)
    Tr.append(1-tst)#train
    te.append(tst)#test
    r2_value.append(r2)
    adj_r2_value.append(ar2)
    RMSE_value.append(rmse)
    #route_name.append(rt[0])
    mn.append("weight 1()")
    max_i_.append(mi)
    max_j_.append(mj)
    max_k_.append(mk)
    max_l_.append(0)
    times.append(0)
    return

# %%
#negative weight DT
def c2(model1,model2,model3,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,tst):
    
    #RF
    #model1=rf(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,1)
    predictions1 = model1.predict(X_test)
    #DT
    #model2=dt(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,1) 
    predictions2 = model2.predict(X_test)
    #BR
    #model3=br(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,1)
    predictions3 = model3.predict(X_test)
    
    
    max_r2=0
    mi=0
    mj=0
    mk=0
    for i in range(-100,301):
        for j in range(-100,301):
            for k in range(-100,301):
                if((i+j+k)==100):
                    #print(i," ",j," ",k)
                    pred=(i/100)*predictions1+(j/100)*predictions2+(k/100)*predictions3
                    r2 = r2_score(y_test, pred)
                    if(r2>max_r2):
                        max_r2=r2
                        mi=i
                        mj=j
                        mk=k
    
    
    predictions = (mi/100)*predictions1+(mj/100)*predictions2+(mk/100)*predictions3
    mse = mean_squared_error(y_test, predictions)

    print("MSE:", mse)

    rmse = np.sqrt(mse)

    print("RMSE:", rmse)

    r2 = r2_score(y_test, predictions)

    print("R2:", r2)
    ar2=1-(1-r2)*((len(X_test)-1)/(len(X_test)-X_test.shape[1]-1))
    print("Adjusted R2:",ar2)
    Tr.append(1-tst)#train
    te.append(tst)#test
    r2_value.append(r2)
    adj_r2_value.append(ar2)
    RMSE_value.append(rmse)
    #route_name.append(rt[0])
    mn.append("weight 2()")
    max_i_.append(mi)
    max_j_.append(mj)
    max_k_.append(mk)
    max_l_.append(0)
    times.append(0)
    return

# %%
#positive weight GBR
def c3(model1,model2,model3,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,tst):
    
    #RF
    #model1=rf(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,1)
    predictions1 = model1.predict(X_test)
    #DT
    #model2=dt(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,1) 
    predictions2 = model2.predict(X_test)
    #BR
    #model3=br(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,1)
    predictions3 = model3.predict(X_test)
    
    
    max_r2=0
    mi=0
    mj=0
    mk=0
    for i in range(0,101):
        for j in range(0,101):
            for k in range(0,101):
                if((i+j+k)==100):
                    #print(i," ",j," ",k)
                    pred=(i/100)*predictions1+(j/100)*predictions2+(k/100)*predictions3
                    r2 = r2_score(y_test, pred)
                    if(r2>max_r2):
                        max_r2=r2
                        mi=i
                        mj=j
                        mk=k
    
    
    predictions = (mi/100)*predictions1+(mj/100)*predictions2+(mk/100)*predictions3
    mse = mean_squared_error(y_test, predictions)

    print("MSE:", mse)

    rmse = np.sqrt(mse)

    print("RMSE:", rmse)

    r2 = r2_score(y_test, predictions)

    print("R2:", r2)
    ar2=1-(1-r2)*((len(X_test)-1)/(len(X_test)-X_test.shape[1]-1))
    print("Adjusted R2:",ar2)
    Tr.append(1-tst)#train
    te.append(tst)#test
    r2_value.append(r2)
    adj_r2_value.append(ar2)
    RMSE_value.append(rmse)
    #route_name.append(rt[0])
    mn.append("weight 3()")
    max_i_.append(mi)
    max_j_.append(0)
    max_k_.append(mk)
    max_l_.append(mj)
    times.append(0)
    return

# %%
#negative weight GBR
def c4(model1,model2,model3,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,tst):
    
    #RF
    #model1=rf(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,1)
    predictions1 = model1.predict(X_test)
    #DT
    #model2=dt(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,1) 
    predictions2 = model2.predict(X_test)
    #BR
    #model3=br(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,1)
    predictions3 = model3.predict(X_test)
    
    
    max_r2=0
    mi=0
    mj=0
    mk=0
    for i in range(-100,301):
        for j in range(-100,301):
            for k in range(-100,301):
                if((i+j+k)==100):
                    #print(i," ",j," ",k)
                    pred=(i/100)*predictions1+(j/100)*predictions2+(k/100)*predictions3
                    r2 = r2_score(y_test, pred)
                    if(r2>max_r2):
                        max_r2=r2
                        mi=i
                        mj=j
                        mk=k
    
    
    predictions = (mi/100)*predictions1+(mj/100)*predictions2+(mk/100)*predictions3
    mse = mean_squared_error(y_test, predictions)

    print("MSE:", mse)

    rmse = np.sqrt(mse)

    print("RMSE:", rmse)

    r2 = r2_score(y_test, predictions)

    print("R2:", r2)
    ar2=1-(1-r2)*((len(X_test)-1)/(len(X_test)-X_test.shape[1]-1))
    print("Adjusted R2:",ar2)
    Tr.append(1-tst)#train
    te.append(tst)#test
    r2_value.append(r2)
    adj_r2_value.append(ar2)
    RMSE_value.append(rmse)
    #route_name.append(rt[0])
    mn.append("weight 4()")
    max_i_.append(mi)
    max_j_.append(mj)
    max_k_.append(mk)
    max_l_.append(0)
    times.append(0)
    return

# %%
import pickle
print("begin")
F=1
for file in g:
    print(F)
    F=F+1
    df=pd.read_csv(file)
    print(df.columns)
    y = df['Price'].values
    X= df.drop(['Price','Unnamed: 0'],axis=1).values
    y=y.astype(float)
    
    # Train the model
    for k in [0.3,0.2,0.1,0.05]:
        
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=k, random_state=0)
        #RF
        print("RF")
        model1=rf(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,0,k)
        #DT
        print("DT")
        model2=dt(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,0,k) 
        #BR
        print("BR")
        model3=br(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,0,k)
        
        #GBR
        print("GBR")
        model4=gbr(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,0,k)
        
        #positive weight DT
        print("c1")
        c1(model1,model2,model3,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,k)
        
        #negative weight DT
        print("c2")
        c2(model1,model2,model3,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,k)
        
        #positive weight GBR
        print("c3")
        c3(model1,model4,model3,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,k)
        
        #negative weight GBR
        print("c4")
        c4(model1,model4,model3,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,k)
        
        print("c5")
        #c5(model1,model2,model3,model4,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,k)
        
        print("c6")
        #c6(model1,model2,model3,model4,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,k)
        
        #model saving
        filename = 'RFmodel'+str(k)+'Bench.pkl'
        pickle.dump(model1, open(filename, 'wb'))
        
        filename = 'DTmodel'+str(k)+'Bench.pkl'
        pickle.dump(model2, open(filename, 'wb'))
        
        filename = 'BRmodel'+str(k)+'Bench.pkl'
        pickle.dump(model3, open(filename, 'wb'))
        
        filename = 'GBRmodel'+str(k)+'Bench.pkl'
        pickle.dump(model4, open(filename, 'wb'))
        
        
        
 
    

print("end")
# Out:
# begin
# 1
# Index(['Unnamed: 0', 'Total_Stops', 'Price', 'Journey_day', 'Journey_month',
#        'Departure_hour', 'Departure_Minute', 'Arrival_Hour', 'Arrival_Minute',
#        'Duration_Hours', 'Duration_Min', 'Airline_Air India', 'Airline_GoAir',
#        'Airline_IndiGo', 'Airline_Jet Airways', 'Airline_Jet Airways Business',
#        'Airline_Multiple carriers',
#        'Airline_Multiple carriers Premium economy', 'Airline_SpiceJet',
#        'Airline_Trujet', 'Airline_Vistara', 'Airline_Vistara Premium economy',
#        'Source_Chennai', 'Source_Delhi', 'Source_Kolkata', 'Source_Mumbai',
#        'Cochin', 'Delhi', 'Hyderabad', 'Kolkata', 'New Delhi'],
#       dtype='object')
# RF
# MSE: 3958103.128738998
# RMSE: 1989.4982102879605
# R2: 0.8166693207422192
# Adjusted R2: 0.8149948043017544
# DT
# MSE: 6815788.454702201
# RMSE: 2610.706504895217
# R2: 0.6843075871355622
# Adjusted R2: 0.681424097380265
# BR
# MSE: 4665890.074234766
# RMSE: 2160.0671457699564
# R2: 0.783886177588274
# Adjusted R2: 0.7819122245646708
# GBR
# Binning 0.002 GB of training data: 0.014 s
# Fitting gradient boosted rounds:
# [1/100] 1 tree, 31 leaves, max depth = 9, in 0.013s
# [2/100] 1 tree, 31 leaves, max depth = 8, in 0.009s
# [3/100] 1 tree, 31 leaves, max depth = 8, in 0.009s
# [4/100] 1 tree, 31 leaves, max depth = 9, in 0.009s
# [5/100] 1 tree, 31 leaves, max depth = 10, in 0.009s
# [6/100] 1 tree, 31 leaves, max depth = 9, in 0.009s
# [7/100] 1 tree, 31 leaves, max depth = 7, in 0.009s
# [8/100] 1 tree, 31 leaves, max depth = 11, in 0.009s
# [9/100] 1 tree, 31 leaves, max depth = 10, in 0.009s
# [10/100] 1 tree, 31 leaves, max depth = 8, in 0.009s
# [11/100] 1 tree, 31 leaves, max depth = 9, in 0.009s
# [12/100] 1 tree, 31 leaves, max depth = 10, in 0.009s
# [13/100] 1 tree, 31 leaves, max depth = 11, in 0.009s
# [14/100] 1 tree, 31 leaves, max depth = 10, in 0.009s
# [15/100] 1 tree, 31 leaves, max depth = 12, in 0.008s
# [16/100] 1 tree, 31 leaves, max depth = 11, in 0.008s
# [17/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [18/100] 1 tree, 31 leaves, max depth = 12, in 0.008s
# [19/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [20/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [21/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [22/100] 1 tree, 31 leaves, max depth = 11, in 0.008s
# [23/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [24/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [25/100] 1 tree, 31 leaves, max depth = 12, in 0.008s
# [26/100] 1 tree, 31 leaves, max depth = 8, in 0.009s
# [27/100] 1 tree, 31 leaves, max depth = 11, in 0.008s
# [28/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [29/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [30/100] 1 tree, 31 leaves, max depth = 11, in 0.008s
# [31/100] 1 tree, 31 leaves, max depth = 11, in 0.008s
# [32/100] 1 tree, 31 leaves, max depth = 8, in 0.008s
# [33/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [34/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [35/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [36/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [37/100] 1 tree, 31 leaves, max depth = 13, in 0.007s
# [38/100] 1 tree, 31 leaves, max depth = 10, in 0.007s
# [39/100] 1 tree, 31 leaves, max depth = 11, in 0.008s
# [40/100] 1 tree, 31 leaves, max depth = 8, in 0.007s
# [41/100] 1 tree, 31 leaves, max depth = 12, in 0.008s
# [42/100] 1 tree, 31 leaves, max depth = 12, in 0.008s
# [43/100] 1 tree, 31 leaves, max depth = 9, in 0.007s
# [44/100] 1 tree, 31 leaves, max depth = 11, in 0.008s
# [45/100] 1 tree, 31 leaves, max depth = 11, in 0.008s
# [46/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [47/100] 1 tree, 31 leaves, max depth = 11, in 0.008s
# [48/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [49/100] 1 tree, 31 leaves, max depth = 10, in 0.009s
# [50/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [51/100] 1 tree, 31 leaves, max depth = 11, in 0.008s
# [52/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [53/100] 1 tree, 31 leaves, max depth = 12, in 0.009s
# [54/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [55/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [56/100] 1 tree, 31 leaves, max depth = 15, in 0.008s
# [57/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [58/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [59/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [60/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [61/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [62/100] 1 tree, 31 leaves, max depth = 11, in 0.008s
# [63/100] 1 tree, 31 leaves, max depth = 11, in 0.008s
# [64/100] 1 tree, 31 leaves, max depth = 8, in 0.008s
# [65/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [66/100] 1 tree, 31 leaves, max depth = 8, in 0.008s
# [67/100] 1 tree, 31 leaves, max depth = 11, in 0.008s
# [68/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [69/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [70/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [71/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [72/100] 1 tree, 31 leaves, max depth = 13, in 0.009s
# [73/100] 1 tree, 31 leaves, max depth = 9, in 0.009s
# [74/100] 1 tree, 31 leaves, max depth = 11, in 0.009s
# [75/100] 1 tree, 31 leaves, max depth = 13, in 0.008s
# [76/100] 1 tree, 31 leaves, max depth = 8, in 0.008s
# [77/100] 1 tree, 31 leaves, max depth = 11, in 0.008s
# [78/100] 1 tree, 31 leaves, max depth = 12, in 0.008s
# [79/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [80/100] 1 tree, 31 leaves, max depth = 12, in 0.008s
# [81/100] 1 tree, 31 leaves, max depth = 14, in 0.008s
# [82/100] 1 tree, 31 leaves, max depth = 11, in 0.008s
# [83/100] 1 tree, 31 leaves, max depth = 8, in 0.008s
# [84/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [85/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [86/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [87/100] 1 tree, 31 leaves, max depth = 12, in 0.008s
# [88/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [89/100] 1 tree, 31 leaves, max depth = 11, in 0.008s
# [90/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [91/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [92/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [93/100] 1 tree, 31 leaves, max depth = 11, in 0.009s
# [94/100] 1 tree, 31 leaves, max depth = 12, in 0.008s
# [95/100] 1 tree, 31 leaves, max depth = 12, in 0.008s
# [96/100] 1 tree, 31 leaves, max depth = 13, in 0.008s
# [97/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [98/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [99/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [100/100] 1 tree, 31 leaves, max depth = 11, in 0.008s
# Fit 100 trees in 0.879 s, (3100 total leaves)
# Time spent computing histograms: 0.140s
# Time spent finding best splits:  0.055s
# Time spent applying splits:      0.132s
# Time spent predicting:           0.010s
# MSE: 4528322.540526472
# RMSE: 2127.9855592852296
# R2: 0.7902580048444764
# Adjusted R2: 0.7883422511879378
# c1
# MSE: 3958103.128738998
# RMSE: 1989.4982102879605
# R2: 0.8166693207422192
# Adjusted R2: 0.8149948043017544
# c2
# MSE: 3837890.5769167435
# RMSE: 1959.0534900601217
# R2: 0.8222373031984789
# Adjusted R2: 0.8206136439206067
# c3
# MSE: 3672671.6957646143
# RMSE: 1916.4215861246748
# R2: 0.8298898803857438
# Adjusted R2: 0.8283361186632829
# c4
# MSE: 3636650.124893465
# RMSE: 1907.0002949379596
# R2: 0.8315583207575449
# Adjusted R2: 0.8300197983329681
# c5
# c6
# RF
# MSE: 4475173.668706543
# RMSE: 2115.460628020891
# R2: 0.8092681968776807
# Adjusted R2: 0.806643032050653
# DT
# MSE: 6961323.19776283
# RMSE: 2638.4319581453738
# R2: 0.703308558746885
# Adjusted R2: 0.699225003077051
# BR
# MSE: 4704377.9604788115
# RMSE: 2168.95780514025
# R2: 0.7994995150142716
# Adjusted R2: 0.7967398975180277
# GBR
# Binning 0.002 GB of training data: 0.013 s
# Fitting gradient boosted rounds:
# [1/100] 1 tree, 31 leaves, max depth = 8, in 0.009s
# [2/100] 1 tree, 31 leaves, max depth = 9, in 0.010s
# [3/100] 1 tree, 31 leaves, max depth = 8, in 0.009s
# [4/100] 1 tree, 31 leaves, max depth = 8, in 0.009s
# [5/100] 1 tree, 31 leaves, max depth = 10, in 0.009s
# [6/100] 1 tree, 31 leaves, max depth = 8, in 0.009s
# [7/100] 1 tree, 31 leaves, max depth = 10, in 0.009s
# [8/100] 1 tree, 31 leaves, max depth = 11, in 0.009s
# [9/100] 1 tree, 31 leaves, max depth = 8, in 0.009s
# [10/100] 1 tree, 31 leaves, max depth = 11, in 0.009s
# [11/100] 1 tree, 31 leaves, max depth = 13, in 0.009s
# [12/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [13/100] 1 tree, 31 leaves, max depth = 11, in 0.009s
# [14/100] 1 tree, 31 leaves, max depth = 9, in 0.009s
# [15/100] 1 tree, 31 leaves, max depth = 11, in 0.009s
# [16/100] 1 tree, 31 leaves, max depth = 8, in 0.009s
# [17/100] 1 tree, 31 leaves, max depth = 8, in 0.008s
# [18/100] 1 tree, 31 leaves, max depth = 14, in 0.009s
# [19/100] 1 tree, 31 leaves, max depth = 9, in 0.009s
# [20/100] 1 tree, 31 leaves, max depth = 8, in 0.009s
# [21/100] 1 tree, 31 leaves, max depth = 9, in 0.009s
# [22/100] 1 tree, 31 leaves, max depth = 11, in 0.008s
# [23/100] 1 tree, 31 leaves, max depth = 9, in 0.009s
# [24/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [25/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [26/100] 1 tree, 31 leaves, max depth = 11, in 0.008s
# [27/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [28/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [29/100] 1 tree, 31 leaves, max depth = 11, in 0.009s
# [30/100] 1 tree, 31 leaves, max depth = 11, in 0.009s
# [31/100] 1 tree, 31 leaves, max depth = 8, in 0.008s
# [32/100] 1 tree, 31 leaves, max depth = 12, in 0.008s
# [33/100] 1 tree, 31 leaves, max depth = 8, in 0.008s
# [34/100] 1 tree, 31 leaves, max depth = 11, in 0.009s
# [35/100] 1 tree, 31 leaves, max depth = 8, in 0.009s
# [36/100] 1 tree, 31 leaves, max depth = 13, in 0.009s
# [37/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [38/100] 1 tree, 31 leaves, max depth = 7, in 0.008s
# [39/100] 1 tree, 31 leaves, max depth = 10, in 0.009s
# [40/100] 1 tree, 31 leaves, max depth = 10, in 0.009s
# [41/100] 1 tree, 31 leaves, max depth = 11, in 0.008s
# [42/100] 1 tree, 31 leaves, max depth = 7, in 0.009s
# [43/100] 1 tree, 31 leaves, max depth = 11, in 0.008s
# [44/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [45/100] 1 tree, 31 leaves, max depth = 10, in 0.009s
# [46/100] 1 tree, 31 leaves, max depth = 8, in 0.008s
# [47/100] 1 tree, 31 leaves, max depth = 8, in 0.008s
# [48/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [49/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [50/100] 1 tree, 31 leaves, max depth = 12, in 0.008s
# [51/100] 1 tree, 31 leaves, max depth = 11, in 0.009s
# [52/100] 1 tree, 31 leaves, max depth = 8, in 0.008s
# [53/100] 1 tree, 31 leaves, max depth = 10, in 0.009s
# [54/100] 1 tree, 31 leaves, max depth = 10, in 0.009s
# [55/100] 1 tree, 31 leaves, max depth = 8, in 0.008s
# [56/100] 1 tree, 31 leaves, max depth = 8, in 0.008s
# [57/100] 1 tree, 31 leaves, max depth = 9, in 0.009s
# [58/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [59/100] 1 tree, 31 leaves, max depth = 11, in 0.008s
# [60/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [61/100] 1 tree, 31 leaves, max depth = 11, in 0.008s
# [62/100] 1 tree, 31 leaves, max depth = 11, in 0.009s
# [63/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [64/100] 1 tree, 31 leaves, max depth = 9, in 0.009s
# [65/100] 1 tree, 31 leaves, max depth = 8, in 0.009s
# [66/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [67/100] 1 tree, 31 leaves, max depth = 12, in 0.008s
# [68/100] 1 tree, 31 leaves, max depth = 11, in 0.008s
# [69/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [70/100] 1 tree, 31 leaves, max depth = 11, in 0.008s
# [71/100] 1 tree, 31 leaves, max depth = 8, in 0.008s
# [72/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [73/100] 1 tree, 31 leaves, max depth = 11, in 0.008s
# [74/100] 1 tree, 31 leaves, max depth = 13, in 0.008s
# [75/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [76/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [77/100] 1 tree, 31 leaves, max depth = 12, in 0.009s
# [78/100] 1 tree, 31 leaves, max depth = 10, in 0.009s
# [79/100] 1 tree, 31 leaves, max depth = 12, in 0.008s
# [80/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [81/100] 1 tree, 31 leaves, max depth = 8, in 0.008s
# [82/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [83/100] 1 tree, 31 leaves, max depth = 8, in 0.009s
# [84/100] 1 tree, 31 leaves, max depth = 9, in 0.009s
# [85/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [86/100] 1 tree, 31 leaves, max depth = 13, in 0.008s
# [87/100] 1 tree, 31 leaves, max depth = 13, in 0.008s
# [88/100] 1 tree, 31 leaves, max depth = 12, in 0.009s
# [89/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [90/100] 1 tree, 31 leaves, max depth = 11, in 0.008s
# [91/100] 1 tree, 31 leaves, max depth = 13, in 0.009s
# [92/100] 1 tree, 31 leaves, max depth = 10, in 0.009s
# [93/100] 1 tree, 31 leaves, max depth = 15, in 0.008s
# [94/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [95/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [96/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [97/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [98/100] 1 tree, 31 leaves, max depth = 11, in 0.009s
# [99/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [100/100] 1 tree, 31 leaves, max depth = 11, in 0.008s
# Fit 100 trees in 0.914 s, (3100 total leaves)
# Time spent computing histograms: 0.143s
# Time spent finding best splits:  0.056s
# Time spent applying splits:      0.133s
# Time spent predicting:           0.012s
# MSE: 5342679.223622236
# RMSE: 2311.4236356891042
# R2: 0.7722951292479898
# Adjusted R2: 0.7691610802438094
# c1
# MSE: 4462436.996780308
# RMSE: 2112.448105109403
# R2: 0.809811033554446
# Adjusted R2: 0.8071933401387263
# c2
# MSE: 4379539.1188286375
# RMSE: 2092.7348419779887
# R2: 0.813344139285582
# Adjusted R2: 0.8107750742828681
# c3
# MSE: 4196662.436422294
# RMSE: 2048.575709223922
# R2: 0.8211383394589288
# Adjusted R2: 0.8186765510604044
# c4
# MSE: 4196662.436422294
# RMSE: 2048.575709223922
# R2: 0.8211383394589288
# Adjusted R2: 0.8186765510604044
# c5
# c6
# RF
# MSE: 4875162.189964369
# RMSE: 2207.9769450708422
# R2: 0.8038413073113706
# Adjusted R2: 0.7983662331169815
# DT
# MSE: 7527590.511582736
# RMSE: 2743.6454784798157
# R2: 0.6971172945000641
# Adjusted R2: 0.6886633980039157
# BR
# MSE: 5340966.204958238
# RMSE: 2311.0530510912636
# R2: 0.7850990577061365
# Adjusted R2: 0.7791008600867698
# GBR
# Binning 0.002 GB of training data: 0.018 s
# Fitting gradient boosted rounds:
# [1/100] 1 tree, 31 leaves, max depth = 7, in 0.010s
# [2/100] 1 tree, 31 leaves, max depth = 8, in 0.010s
# [3/100] 1 tree, 31 leaves, max depth = 8, in 0.010s
# [4/100] 1 tree, 31 leaves, max depth = 11, in 0.010s
# [5/100] 1 tree, 31 leaves, max depth = 9, in 0.010s
# [6/100] 1 tree, 31 leaves, max depth = 11, in 0.009s
# [7/100] 1 tree, 31 leaves, max depth = 10, in 0.010s
# [8/100] 1 tree, 31 leaves, max depth = 14, in 0.009s
# [9/100] 1 tree, 31 leaves, max depth = 8, in 0.009s
# [10/100] 1 tree, 31 leaves, max depth = 10, in 0.009s
# [11/100] 1 tree, 31 leaves, max depth = 8, in 0.009s
# [12/100] 1 tree, 31 leaves, max depth = 8, in 0.009s
# [13/100] 1 tree, 31 leaves, max depth = 10, in 0.009s
# [14/100] 1 tree, 31 leaves, max depth = 14, in 0.009s
# [15/100] 1 tree, 31 leaves, max depth = 9, in 0.009s
# [16/100] 1 tree, 31 leaves, max depth = 10, in 0.009s
# [17/100] 1 tree, 31 leaves, max depth = 12, in 0.009s
# [18/100] 1 tree, 31 leaves, max depth = 10, in 0.009s
# [19/100] 1 tree, 31 leaves, max depth = 7, in 0.008s
# [20/100] 1 tree, 31 leaves, max depth = 13, in 0.009s
# [21/100] 1 tree, 31 leaves, max depth = 10, in 0.009s
# [22/100] 1 tree, 31 leaves, max depth = 10, in 0.009s
# [23/100] 1 tree, 31 leaves, max depth = 9, in 0.009s
# [24/100] 1 tree, 31 leaves, max depth = 10, in 0.009s
# [25/100] 1 tree, 31 leaves, max depth = 10, in 0.009s
# [26/100] 1 tree, 31 leaves, max depth = 11, in 0.009s
# [27/100] 1 tree, 31 leaves, max depth = 8, in 0.009s
# [28/100] 1 tree, 31 leaves, max depth = 10, in 0.009s
# [29/100] 1 tree, 31 leaves, max depth = 10, in 0.009s
# [30/100] 1 tree, 31 leaves, max depth = 8, in 0.008s
# [31/100] 1 tree, 31 leaves, max depth = 9, in 0.009s
# [32/100] 1 tree, 31 leaves, max depth = 10, in 0.009s
# [33/100] 1 tree, 31 leaves, max depth = 11, in 0.009s
# [34/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [35/100] 1 tree, 31 leaves, max depth = 10, in 0.009s
# [36/100] 1 tree, 31 leaves, max depth = 11, in 0.008s
# [37/100] 1 tree, 31 leaves, max depth = 10, in 0.009s
# [38/100] 1 tree, 31 leaves, max depth = 10, in 0.009s
# [39/100] 1 tree, 31 leaves, max depth = 11, in 0.009s
# [40/100] 1 tree, 31 leaves, max depth = 9, in 0.009s
# [41/100] 1 tree, 31 leaves, max depth = 13, in 0.008s
# [42/100] 1 tree, 31 leaves, max depth = 12, in 0.009s
# [43/100] 1 tree, 31 leaves, max depth = 9, in 0.009s
# [44/100] 1 tree, 31 leaves, max depth = 8, in 0.009s
# [45/100] 1 tree, 31 leaves, max depth = 9, in 0.009s
# [46/100] 1 tree, 31 leaves, max depth = 11, in 0.009s
# [47/100] 1 tree, 31 leaves, max depth = 9, in 0.009s
# [48/100] 1 tree, 31 leaves, max depth = 10, in 0.009s
# [49/100] 1 tree, 31 leaves, max depth = 9, in 0.009s
# [50/100] 1 tree, 31 leaves, max depth = 11, in 0.009s
# [51/100] 1 tree, 31 leaves, max depth = 9, in 0.009s
# [52/100] 1 tree, 31 leaves, max depth = 10, in 0.009s
# [53/100] 1 tree, 31 leaves, max depth = 8, in 0.009s
# [54/100] 1 tree, 31 leaves, max depth = 10, in 0.009s
# [55/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [56/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [57/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [58/100] 1 tree, 31 leaves, max depth = 11, in 0.009s
# [59/100] 1 tree, 31 leaves, max depth = 10, in 0.009s
# [60/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [61/100] 1 tree, 31 leaves, max depth = 10, in 0.009s
# [62/100] 1 tree, 31 leaves, max depth = 14, in 0.009s
# [63/100] 1 tree, 31 leaves, max depth = 8, in 0.009s
# [64/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [65/100] 1 tree, 31 leaves, max depth = 12, in 0.008s
# [66/100] 1 tree, 31 leaves, max depth = 11, in 0.008s
# [67/100] 1 tree, 31 leaves, max depth = 11, in 0.009s
# [68/100] 1 tree, 31 leaves, max depth = 11, in 0.008s
# [69/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [70/100] 1 tree, 31 leaves, max depth = 9, in 0.009s
# [71/100] 1 tree, 31 leaves, max depth = 12, in 0.008s
# [72/100] 1 tree, 31 leaves, max depth = 10, in 0.009s
# [73/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [74/100] 1 tree, 31 leaves, max depth = 8, in 0.008s
# [75/100] 1 tree, 31 leaves, max depth = 8, in 0.008s
# [76/100] 1 tree, 31 leaves, max depth = 11, in 0.008s
# [77/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [78/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [79/100] 1 tree, 31 leaves, max depth = 11, in 0.008s
# [80/100] 1 tree, 31 leaves, max depth = 11, in 0.008s
# [81/100] 1 tree, 31 leaves, max depth = 8, in 0.008s
# [82/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [83/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [84/100] 1 tree, 31 leaves, max depth = 12, in 0.008s
# [85/100] 1 tree, 31 leaves, max depth = 8, in 0.008s
# [86/100] 1 tree, 31 leaves, max depth = 14, in 0.008s
# [87/100] 1 tree, 31 leaves, max depth = 8, in 0.008s
# [88/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [89/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [90/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [91/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [92/100] 1 tree, 31 leaves, max depth = 11, in 0.008s
# [93/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [94/100] 1 tree, 31 leaves, max depth = 11, in 0.008s
# [95/100] 1 tree, 31 leaves, max depth = 12, in 0.008s
# [96/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [97/100] 1 tree, 31 leaves, max depth = 9, in 0.008s
# [98/100] 1 tree, 31 leaves, max depth = 10, in 0.008s
# [99/100] 1 tree, 31 leaves, max depth = 9, in 0.009s
# [100/100] 1 tree, 31 leaves, max depth = 11, in 0.008s
# Fit 100 trees in 0.923 s, (3100 total leaves)
# Time spent computing histograms: 0.145s
# Time spent finding best splits:  0.057s
# Time spent applying splits:      0.133s
# Time spent predicting:           0.012s
# MSE: 4870503.693454837
# RMSE: 2206.9217687663595
# R2: 0.8040287481696635
# Adjusted R2: 0.798558905722041
# c1
# MSE: 4875162.189964369
# RMSE: 2207.9769450708422
# [81/100] 1 tree, 31 leaves, max depth = 8, train loss: 83.55889, val loss: 134.73158, in 0.010s
# [82/100] 1 tree, 31 leaves, max depth = 11, train loss: 83.06746, val loss: 134.63527, in 0.009s
# [83/100] 1 tree, 31 leaves, max depth = 11, train loss: 82.71428, val loss: 134.39428, in 0.009s
# [84/100] 1 tree, 31 leaves, max depth = 8, train loss: 82.22186, val loss: 134.13276, in 0.010s
# [85/100] 1 tree, 31 leaves, max depth = 12, train loss: 81.92986, val loss: 134.03020, in 0.020s
# [86/100] 1 tree, 31 leaves, max depth = 11, train loss: 81.56262, val loss: 134.20394, in 0.027s
# [87/100] 1 tree, 31 leaves, max depth = 10, train loss: 80.92141, val loss: 133.99784, in 0.018s
# [88/100] 1 tree, 31 leaves, max depth = 11, train loss: 80.70414, val loss: 133.98846, in 0.419s
# [89/100] 1 tree, 31 leaves, max depth = 9, train loss: 80.41657, val loss: 133.63202, in 0.009s
# [90/100] 1 tree, 31 leaves, max depth = 9, train loss: 80.22959, val loss: 133.61195, in 0.010s
# [91/100] 1 tree, 31 leaves, max depth = 13, train loss: 79.77446, val loss: 133.40766, in 0.009s
# [92/100] 1 tree, 31 leaves, max depth = 12, train loss: 79.54208, val loss: 133.57832, in 0.009s
# [93/100] 1 tree, 31 leaves, max depth = 8, train loss: 79.29054, val loss: 133.07462, in 0.009s
# [94/100] 1 tree, 31 leaves, max depth = 8, train loss: 79.00342, val loss: 133.27896, in 0.009s
# [95/100] 1 tree, 31 leaves, max depth = 12, train loss: 78.69256, val loss: 133.19226, in 0.009s
# [96/100] 1 tree, 31 leaves, max depth = 11, train loss: 78.40632, val loss: 133.23227, in 0.009s
# [97/100] 1 tree, 31 leaves, max depth = 14, train loss: 78.15456, val loss: 133.48167, in 0.009s
# [98/100] 1 tree, 31 leaves, max depth = 10, train loss: 77.99627, val loss: 133.54100, in 0.009s
# [99/100] 1 tree, 31 leaves, max depth = 13, train loss: 77.72431, val loss: 133.70327, in 0.010s
# [100/100] 1 tree, 31 leaves, max depth = 10, train loss: 77.41430, val loss: 133.88169, in 0.010s
# Fit 100 trees in 1.827 s, (3100 total leaves)
# Time spent computing histograms: 0.263s
# Time spent finding best splits:  0.111s
# Time spent applying splits:      0.296s
# Time spent predicting:           0.061s
# MSE: 6936219.489930798
# RMSE: 2633.670345721119
# R2: 0.7583599313291927
# Adjusted R2: 0.744483570950077
# c1
# MSE: 5599715.405891588
# RMSE: 2366.371780995452
# R2: 0.8049203002902492
# Adjusted R2: 0.7937177036732536
# c2
# MSE: 5038534.934070895
# RMSE: 2244.6681122319387
# R2: 0.8244703863197242
# Adjusted R2: 0.8143904679103618
# c3
# MSE: 5590967.848580723
# RMSE: 2364.5227528151895
# R2: 0.8052250427154808
# Adjusted R2: 0.794039946158548
# c4
# MSE: 5431219.744758142
# RMSE: 2330.497746138825
# R2: 0.8107902562779634
# Adjusted R2: 0.7999247462424405
# c5
# c6
# end

# %%
df=pd.DataFrame([pd.Series(mn),pd.Series(Tr),pd.Series(te),pd.Series(r2_value),pd.Series(adj_r2_value),pd.Series(RMSE_value),
                pd.Series(max_i_),pd.Series(max_j_),pd.Series(max_k_),pd.Series(max_l_),pd.Series(times)], 
                index = ["Model Name","Train size","Test size","r2","Adjusted r2","RMSE",
                         "RF weight","DT weight","BR weight value","GBR weight","Time"])
df.head()
# Out:
#                                   0                        1   \
# Model Name   RandomForestRegressor()  DecisionTreeRegressor()
# Train size                       0.7                      0.7
# Test size                        0.3                      0.3
# r2                          0.816669                 0.684308
# Adjusted r2                 0.814995                 0.681424
#
#                              2                            3           4   \
# Model Name   BaggingRegressor()  GradientBoostingRegressor()  weight 1()
# Train size                  0.7                          0.7         0.7
# Test size                   0.3                          0.3         0.3
# r2                     0.783886                     0.790258    0.816669
# Adjusted r2            0.781912                     0.788342    0.814995
#
#                      5           6           7                        8   \
# Model Name   weight 2()  weight 3()  weight 4()  RandomForestRegressor()
# Train size          0.7         0.7         0.7                      0.8
# Test size           0.3         0.3         0.3                      0.2
# r2             0.822237     0.82989    0.831558                 0.809268
# Adjusted r2    0.820614    0.828336     0.83002                 0.806643
#
#                                   9   ...          22          23  \
# Model Name   DecisionTreeRegressor()  ...  weight 3()  weight 4()
# Train size                       0.8  ...         0.9         0.9
# Test size                        0.2  ...         0.1         0.1
# r2                          0.703309  ...    0.814606     0.81727
# Adjusted r2                 0.699225  ...    0.809432     0.81217
#
#                                   24                       25  \
# Model Name   RandomForestRegressor()  DecisionTreeRegressor()
# Train size                      0.95                     0.95
# Test size                       0.05                     0.05
# r2                          0.784054                 0.681867
# Adjusted r2                 0.771653                 0.663598
#
#                              26                           27          28  \
# Model Name   BaggingRegressor()  GradientBoostingRegressor()  weight 1()
# Train size                 0.95                         0.95        0.95
# Test size                  0.05                         0.05        0.05
# r2                      0.80492                      0.75836     0.80492
# Adjusted r2            0.793718                     0.744484    0.793718
#
#                      29          30          31
# Model Name   weight 2()  weight 3()  weight 4()
# Train size         0.95        0.95        0.95
# Test size          0.05        0.05        0.05
# r2              0.82447    0.805225     0.81079
# Adjusted r2     0.81439     0.79404    0.799925
#
# [5 rows x 32 columns]

# %%
df1=df.T
df1.head()
# Out:
#                     Model Name Train size Test size        r2 Adjusted r2  \
# 0      RandomForestRegressor()        0.7       0.3  0.816669    0.814995
# 1      DecisionTreeRegressor()        0.7       0.3  0.684308    0.681424
# 2           BaggingRegressor()        0.7       0.3  0.783886    0.781912
# 3  GradientBoostingRegressor()        0.7       0.3  0.790258    0.788342
# 4                   weight 1()        0.7       0.3  0.816669    0.814995
#
#           RMSE RF weight DT weight BR weight value GBR weight      Time
# 0   1989.49821         0         0               0          0  2.582972
# 1  2610.706505         0         0               0          0  0.036717
# 2  2160.067146         0         0               0          0  0.275899
# 3  2127.985559         0         0               0          0  0.881431
# 4   1989.49821       100         0               0          0       0.0

# %%
df1.to_csv("Table.csv")

# %%
df1
# Out:
#                      Model Name Train size Test size        r2 Adjusted r2  \
# 0       RandomForestRegressor()        0.7       0.3  0.816669    0.814995
# 1       DecisionTreeRegressor()        0.7       0.3  0.684308    0.681424
# 2            BaggingRegressor()        0.7       0.3  0.783886    0.781912
# 3   GradientBoostingRegressor()        0.7       0.3  0.790258    0.788342
# 4                    weight 1()        0.7       0.3  0.816669    0.814995
# 5                    weight 2()        0.7       0.3  0.822237    0.820614
# 6                    weight 3()        0.7       0.3   0.82989    0.828336
# 7                    weight 4()        0.7       0.3  0.831558     0.83002
# 8       RandomForestRegressor()        0.8       0.2  0.809268    0.806643
# 9       DecisionTreeRegressor()        0.8       0.2  0.703309    0.699225
# 10           BaggingRegressor()        0.8       0.2    0.7995     0.79674
# 11  GradientBoostingRegressor()        0.8       0.2  0.772295    0.769161
# 12                   weight 1()        0.8       0.2  0.809811    0.807193
# 13                   weight 2()        0.8       0.2  0.813344    0.810775
# 14                   weight 3()        0.8       0.2  0.821138    0.818677
# 15                   weight 4()        0.8       0.2  0.821138    0.818677
# 16      RandomForestRegressor()        0.9       0.1  0.803841    0.798366
# 17      DecisionTreeRegressor()        0.9       0.1  0.697117    0.688663
# 18           BaggingRegressor()        0.9       0.1  0.785099    0.779101
# 19  GradientBoostingRegressor()        0.9       0.1  0.804029    0.798559
# 20                   weight 1()        0.9       0.1  0.803841    0.798366
# 21                   weight 2()        0.9       0.1  0.813856    0.808661
# 22                   weight 3()        0.9       0.1  0.814606    0.809432
# 23                   weight 4()        0.9       0.1   0.81727     0.81217
# 24      RandomForestRegressor()       0.95      0.05  0.784054    0.771653
# 25      DecisionTreeRegressor()       0.95      0.05  0.681867    0.663598
# 26           BaggingRegressor()       0.95      0.05   0.80492    0.793718
# 27  GradientBoostingRegressor()       0.95      0.05   0.75836    0.744484
# 28                   weight 1()       0.95      0.05   0.80492    0.793718
# 29                   weight 2()       0.95      0.05   0.82447     0.81439
# 30                   weight 3()       0.95      0.05  0.805225     0.79404
# 31                   weight 4()       0.95      0.05   0.81079    0.799925
#
#            RMSE RF weight DT weight BR weight value GBR weight      Time
# 0    1989.49821         0         0               0          0  2.582972
# 1   2610.706505         0         0               0          0  0.036717
# 2   2160.067146         0         0               0          0  0.275899
# 3   2127.985559         0         0               0          0  0.881431
# 4    1989.49821       100         0               0          0       0.0
# 5    1959.05349       155       -14             -41          0       0.0
# 6   1916.421586        63         0               0         37       0.0
# 7   1907.000295        98        34             -32          0       0.0
# 8   2115.460628         0         0               0          0  2.926064
# 9   2638.431958         0         0               0          0  0.041016
# 10  2168.957805         0         0               0          0  0.298089
# 11  2311.423636         0         0               0          0  0.915973
# 12  2112.448105        81         0              19          0       0.0
# 13  2092.734842        99       -22              23          0       0.0
# 14  2048.575709        32         0              34         34       0.0
# 15  2048.575709        32        34              34          0       0.0
# 16  2207.976945         0         0               0          0  3.278046
# 17  2743.645478         0         0               0          0  0.046289
# 18  2311.053051         0         0               0          0  0.338494
# 19  2206.921769         0         0               0          0  0.924786
# 20  2207.976945       100         0               0          0       0.0
# 21  2150.873654       168       -38             -30          0       0.0
# 22  2146.536895        50         0               0         50       0.0
# 23  2131.060663        98        53             -51          0       0.0
# 24  2489.715883         0         0               0          0  3.326445
# 25  3021.908978         0         0               0          0  0.048383
# 26  2366.371781         0         0               0          0  0.350303
# 27  2633.670346         0         0               0          0  1.828986
# 28  2366.371781         0         0             100          0       0.0
# 29  2244.668112       -11       -57             168          0       0.0
# 30  2364.522753         0         0              93          7       0.0
# 31  2330.497746       -86        22             164          0       0.0
