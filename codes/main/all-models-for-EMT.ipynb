# %%
# Version 1
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
import time
import glob
g=glob.glob('../input/easemytrip-ff-sample-data-processed/EaseMyTrip.csv')
r2_value=[]
adj_r2_value=[]
RMSE_value=[]
#route_name=[]
Tr=[]
te=[]
mn=[]
max_i_=[]
max_j_=[]
max_k_=[]
max_l_=[]
times=[]

# %%
g
# Out:
# ['../input/easemytrip-ff-sample-data-processed/EaseMyTrip.csv']

# %%
#descision tree
from sklearn.tree import DecisionTreeRegressor
def dt(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,o,k):
    start = time.time()
    model = DecisionTreeRegressor().fit(X_train, y_train)
    stop = time.time()
    if o==0:
        predictions = model.predict(X_test)
        mse = mean_squared_error(y_test, predictions)

        print("MSE:", mse)

        rmse = np.sqrt(mse)

        print("RMSE:", rmse)

        r2 = r2_score(y_test, predictions)

        print("R2:", r2)
        ar2=1-(1-r2)*((len(X_test)-1)/(len(X_test)-X_test.shape[1]-1))
        print("Adjusted R2:",ar2)
        Tr.append(1-k)#train
        te.append(k)#test
        r2_value.append(r2)
        adj_r2_value.append(ar2)
        RMSE_value.append(rmse)
        #route_name.append(rt[0])
        mn.append("DecisionTreeRegressor()")
        max_i_.append(0)
        max_j_.append(0)
        max_k_.append(0)
        max_l_.append(0)
        times.append(stop-start)
    return model

# %%
#Random Forest
from sklearn.ensemble import RandomForestRegressor
def rf(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,o,k):
    start = time.time()
    model = RandomForestRegressor().fit(X_train, y_train)
    stop = time.time()
    if o==0:
        predictions = model.predict(X_test)
        mse = mean_squared_error(y_test, predictions)

        print("MSE:", mse)

        rmse = np.sqrt(mse)

        print("RMSE:", rmse)

        r2 = r2_score(y_test, predictions)

        print("R2:", r2)
        ar2=1-(1-r2)*((len(X_test)-1)/(len(X_test)-X_test.shape[1]-1))
        print("Adjusted R2:",ar2)
        Tr.append(1-k)#train
        te.append(k)#test
        r2_value.append(r2)
        adj_r2_value.append(ar2)
        RMSE_value.append(rmse)
        #route_name.append(rt[0])
        mn.append("RandomForestRegressor()")
        max_i_.append(0)
        max_j_.append(0)
        max_k_.append(0)
        max_l_.append(0)
        times.append(stop-start)
    return model

# %%
#Bagging Regressor
from sklearn.ensemble import BaggingRegressor
def br(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,o,k):
    start = time.time()
    model = BaggingRegressor().fit(X_train, y_train)
    stop = time.time()
    if o==0:
        predictions = model.predict(X_test)
        mse = mean_squared_error(y_test, predictions)

        print("MSE:", mse)

        rmse = np.sqrt(mse)

        print("RMSE:", rmse)

        r2 = r2_score(y_test, predictions)

        print("R2:", r2)
        ar2=1-(1-r2)*((len(X_test)-1)/(len(X_test)-X_test.shape[1]-1))
        print("Adjusted R2:",ar2)
        Tr.append(1-k)#train
        te.append(k)#test
        r2_value.append(r2)
        adj_r2_value.append(ar2)
        RMSE_value.append(rmse)
        #route_name.append(rt[0])
        mn.append("BaggingRegressor()")
        max_i_.append(0)
        max_j_.append(0)
        max_k_.append(0)
        max_l_.append(0)
        times.append(stop-start)
    return model

# %%
#
from sklearn.experimental import enable_hist_gradient_boosting 
from sklearn.ensemble import HistGradientBoostingRegressor

def gbr(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,o,k):
    params = {
              #'n_trees_per_iteration_':2,
          #'max_depth': 4,
          #'min_samples_split': 5,
          'learning_rate': 0.3,#[0.1,0.15,0.2,0.175,0.225],
          'loss': 'poisson',#[‘least_squares’, ‘least_absolute_deviation’, ‘poisson’],
            'verbose':2}
    start = time.time()
    model = HistGradientBoostingRegressor(**params).fit(X_train, y_train)
    stop = time.time()
    if o==0:
        predictions = model.predict(X_test)
        mse = mean_squared_error(y_test, predictions)

        print("MSE:", mse)

        rmse = np.sqrt(mse)

        print("RMSE:", rmse)

        r2 = r2_score(y_test, predictions)

        print("R2:", r2)
        ar2=1-(1-r2)*((len(X_test)-1)/(len(X_test)-X_test.shape[1]-1))
        print("Adjusted R2:",ar2)
        Tr.append(1-k)#train
        te.append(k)#test
        r2_value.append(r2)
        adj_r2_value.append(ar2)
        RMSE_value.append(rmse)
        #route_name.append(rt[0])
        mn.append("GradientBoostingRegressor()")
        max_i_.append(0)
        max_j_.append(0)
        max_k_.append(0)
        max_l_.append(0)
        times.append(stop-start)
    return model

# %%
#positive weight DT
def c1(model1,model2,model3,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,tst):
    
    #RF
    #model1=rf(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,1)
    predictions1 = model1.predict(X_test)
    #DT
    #model2=dt(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,1) 
    predictions2 = model2.predict(X_test)
    #BR
    #model3=br(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,1)
    predictions3 = model3.predict(X_test)
    
    
    max_r2=0
    mi=0
    mj=0
    mk=0
    for i in range(0,101):
        for j in range(0,101):
            for k in range(0,101):
                if((i+j+k)==100):
                    #print(i," ",j," ",k)
                    pred=(i/100)*predictions1+(j/100)*predictions2+(k/100)*predictions3
                    r2 = r2_score(y_test, pred)
                    if(r2>max_r2):
                        max_r2=r2
                        mi=i
                        mj=j
                        mk=k
    
    
    predictions = (mi/100)*predictions1+(mj/100)*predictions2+(mk/100)*predictions3
    mse = mean_squared_error(y_test, predictions)

    print("MSE:", mse)

    rmse = np.sqrt(mse)

    print("RMSE:", rmse)

    r2 = r2_score(y_test, predictions)

    print("R2:", r2)
    ar2=1-(1-r2)*((len(X_test)-1)/(len(X_test)-X_test.shape[1]-1))
    print("Adjusted R2:",ar2)
    Tr.append(1-tst)#train
    te.append(tst)#test
    r2_value.append(r2)
    adj_r2_value.append(ar2)
    RMSE_value.append(rmse)
    #route_name.append(rt[0])
    mn.append("weight 1()")
    max_i_.append(mi)
    max_j_.append(mj)
    max_k_.append(mk)
    max_l_.append(0)
    times.append(0)
    return

# %%
#negative weight DT
def c2(model1,model2,model3,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,tst):
    
    #RF
    #model1=rf(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,1)
    predictions1 = model1.predict(X_test)
    #DT
    #model2=dt(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,1) 
    predictions2 = model2.predict(X_test)
    #BR
    #model3=br(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,1)
    predictions3 = model3.predict(X_test)
    
    
    max_r2=0
    mi=0
    mj=0
    mk=0
    for i in range(-100,301):
        for j in range(-100,301):
            for k in range(-100,301):
                if((i+j+k)==100):
                    #print(i," ",j," ",k)
                    pred=(i/100)*predictions1+(j/100)*predictions2+(k/100)*predictions3
                    r2 = r2_score(y_test, pred)
                    if(r2>max_r2):
                        max_r2=r2
                        mi=i
                        mj=j
                        mk=k
    
    
    predictions = (mi/100)*predictions1+(mj/100)*predictions2+(mk/100)*predictions3
    mse = mean_squared_error(y_test, predictions)

    print("MSE:", mse)

    rmse = np.sqrt(mse)

    print("RMSE:", rmse)

    r2 = r2_score(y_test, predictions)

    print("R2:", r2)
    ar2=1-(1-r2)*((len(X_test)-1)/(len(X_test)-X_test.shape[1]-1))
    print("Adjusted R2:",ar2)
    Tr.append(1-tst)#train
    te.append(tst)#test
    r2_value.append(r2)
    adj_r2_value.append(ar2)
    RMSE_value.append(rmse)
    #route_name.append(rt[0])
    mn.append("weight 2()")
    max_i_.append(mi)
    max_j_.append(mj)
    max_k_.append(mk)
    max_l_.append(0)
    times.append(0)
    return

# %%
#positive weight GBR
def c3(model1,model2,model3,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,tst):
    
    #RF
    #model1=rf(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,1)
    predictions1 = model1.predict(X_test)
    #DT
    #model2=dt(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,1) 
    predictions2 = model2.predict(X_test)
    #BR
    #model3=br(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,1)
    predictions3 = model3.predict(X_test)
    
    
    max_r2=0
    mi=0
    mj=0
    mk=0
    for i in range(0,101):
        for j in range(0,101):
            for k in range(0,101):
                if((i+j+k)==100):
                    #print(i," ",j," ",k)
                    pred=(i/100)*predictions1+(j/100)*predictions2+(k/100)*predictions3
                    r2 = r2_score(y_test, pred)
                    if(r2>max_r2):
                        max_r2=r2
                        mi=i
                        mj=j
                        mk=k
    
    
    predictions = (mi/100)*predictions1+(mj/100)*predictions2+(mk/100)*predictions3
    mse = mean_squared_error(y_test, predictions)

    print("MSE:", mse)

    rmse = np.sqrt(mse)

    print("RMSE:", rmse)

    r2 = r2_score(y_test, predictions)

    print("R2:", r2)
    ar2=1-(1-r2)*((len(X_test)-1)/(len(X_test)-X_test.shape[1]-1))
    print("Adjusted R2:",ar2)
    Tr.append(1-tst)#train
    te.append(tst)#test
    r2_value.append(r2)
    adj_r2_value.append(ar2)
    RMSE_value.append(rmse)
    #route_name.append(rt[0])
    mn.append("weight 3()")
    max_i_.append(mi)
    max_j_.append(0)
    max_k_.append(mk)
    max_l_.append(mj)
    times.append(0)
    return

# %%
#negative weight GBR
def c4(model1,model2,model3,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,tst):
    
    #RF
    #model1=rf(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,1)
    predictions1 = model1.predict(X_test)
    #DT
    #model2=dt(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,1) 
    predictions2 = model2.predict(X_test)
    #BR
    #model3=br(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,1)
    predictions3 = model3.predict(X_test)
    
    
    max_r2=0
    mi=0
    mj=0
    mk=0
    for i in range(-100,301):
        for j in range(-100,301):
            for k in range(-100,301):
                if((i+j+k)==100):
                    #print(i," ",j," ",k)
                    pred=(i/100)*predictions1+(j/100)*predictions2+(k/100)*predictions3
                    r2 = r2_score(y_test, pred)
                    if(r2>max_r2):
                        max_r2=r2
                        mi=i
                        mj=j
                        mk=k
    
    
    predictions = (mi/100)*predictions1+(mj/100)*predictions2+(mk/100)*predictions3
    mse = mean_squared_error(y_test, predictions)

    print("MSE:", mse)

    rmse = np.sqrt(mse)

    print("RMSE:", rmse)

    r2 = r2_score(y_test, predictions)

    print("R2:", r2)
    ar2=1-(1-r2)*((len(X_test)-1)/(len(X_test)-X_test.shape[1]-1))
    print("Adjusted R2:",ar2)
    Tr.append(1-tst)#train
    te.append(tst)#test
    r2_value.append(r2)
    adj_r2_value.append(ar2)
    RMSE_value.append(rmse)
    #route_name.append(rt[0])
    mn.append("weight 4()")
    max_i_.append(mi)
    max_j_.append(0)
    max_k_.append(mk)
    max_l_.append(mj)
    times.append(0)
    return

# %%
import pickle
print("begin")
F=1
for file in g:
    print(F)
    F=F+1
    df=pd.read_csv(file)
    print(df.columns)
    y = df['Fare'].values
    X= df.drop(['Fare','Unnamed: 0'],axis=1).values
    y=y.astype(float)
    
    # Train the model
    for k in [0.3,0.2,0.1,0.05]:
        
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=k, random_state=0)
        #RF
        print("RF")
        model1=rf(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,0,k)
        #DT
        print("DT")
        model2=dt(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,0,k) 
        #BR
        print("BR")
        model3=br(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,0,k)
        
        #GBR
        print("BR")
        model4=gbr(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,0,k)
        
        #positive weight DT
        print("c1")
        c1(model1,model2,model3,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,k)
        
        #negative weight DT
        print("c2")
        c2(model1,model2,model3,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,k)
        
        #positive weight GBR
        print("c3")
        c3(model1,model4,model3,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,k)
        
        #negative weight GBR
        print("c4")
        c4(model1,model4,model3,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,k)
        
        print("c5")
        #c5(model1,model2,model3,model4,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,k)
        
        print("c6")
        #c6(model1,model2,model3,model4,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,k)
        
        #model saving
        filename = 'RFmodel'+str(k)+'.pkl'
        pickle.dump(model1, open(filename, 'wb'))
        
        filename = 'DTmodel'+str(k)+'.pkl'
        pickle.dump(model2, open(filename, 'wb'))
        
        filename = 'BRmodel'+str(k)+'.pkl'
        pickle.dump(model3, open(filename, 'wb'))
        
        filename = 'GBRmodel'+str(k)+'.pkl'
        pickle.dump(model4, open(filename, 'wb'))
        
        
        
 
    

print("end")
# Out:
# begin
# 1
# Index(['Unnamed: 0', 'Number Of Stops', 'Fare', 'Days Left', 'Departure_day',
#        'Departure_month', 'Departure_year', 'Departure_hour',
#        'Departure_minute', 'F1_Air Canada',
#        ...
#        'Layover1_Tiruchirapally', 'Layover1_Tirupati', 'Layover1_Tokyo',
#        'Layover1_Udaipur', 'Layover1_VDY', 'Layover1_Vadodara',
#        'Layover1_Varanasi', 'Layover1_Vijayawada', 'Layover1_Vishakhapatnam',
#        'Layover1_Warsaw'],
#       dtype='object', length=366)
# RF
# MSE: 45807131.11414554
# RMSE: 6768.096565072453
# R2: 0.8860247570420065
# Adjusted R2: 0.8774477488888723
# DT
# MSE: 43318177.032963604
# RMSE: 6581.654581711471
# R2: 0.8922176606186811
# Adjusted R2: 0.8841066886247179
# BR
# MSE: 49114124.32426156
# RMSE: 7008.1469964792805
# R2: 0.8777964453050373
# Adjusted R2: 0.8686002299010749
# BR
# Binning 0.032 GB of training data: 0.199 s
# Binning 0.004 GB of validation data: 0.007 s
# Fitting gradient boosted rounds:
# [1/100] 1 tree, 31 leaves, max depth = 18, train loss: 182100.96644, val loss: 296300.76362, in 0.048s
# [2/100] 1 tree, 31 leaves, max depth = 19, train loss: 134222.23650, val loss: 218372.85550, in 0.028s
# [3/100] 1 tree, 31 leaves, max depth = 21, train loss: 98814.06431, val loss: 160700.23325, in 0.030s
# [4/100] 1 tree, 31 leaves, max depth = 15, train loss: 72703.25004, val loss: 118159.16423, in 0.028s
# [5/100] 1 tree, 31 leaves, max depth = 15, train loss: 53439.15184, val loss: 86756.29222, in 0.031s
# [6/100] 1 tree, 31 leaves, max depth = 24, train loss: 39201.98371, val loss: 63575.85456, in 0.040s
# [7/100] 1 tree, 31 leaves, max depth = 23, train loss: 28711.61616, val loss: 46428.24069, in 0.036s
# [8/100] 1 tree, 31 leaves, max depth = 13, train loss: 20974.85180, val loss: 33826.24879, in 0.027s
# [9/100] 1 tree, 31 leaves, max depth = 16, train loss: 15294.33611, val loss: 24579.97866, in 0.028s
# [10/100] 1 tree, 31 leaves, max depth = 17, train loss: 11109.26572, val loss: 17794.94792, in 0.030s
# Fit 10 trees in 0.603 s, (310 total leaves)
# Time spent computing histograms: 0.171s
# Time spent finding best splits:  0.015s
# Time spent applying splits:      0.019s
# Time spent predicting:           0.001s
# MSE: 56342164448.37637
# RMSE: 237365.0447062001
# R2: -139.18803897107387
# Adjusted R2: -149.7376453770013
# c1
# MSE: 41029783.603377596
# RMSE: 6405.449523911464
# R2: 0.8979115382044791
# Adjusted R2: 0.8902290490389696
# c2
# MSE: 41029783.603377596
# RMSE: 6405.449523911464
# R2: 0.8979115382044791
# Adjusted R2: 0.8902290490389696
# c3
# MSE: 45807131.11414554
# RMSE: 6768.096565072453
# R2: 0.8860247570420065
# Adjusted R2: 0.8774477488888723
# c4
# MSE: 45790729.87902221
# RMSE: 6766.884798710719
# R2: 0.8860655658574141
# Adjusted R2: 0.8774916287005191
# c5
# c6
# RF
# MSE: 66626783.623155855
# RMSE: 8162.523116240214
# R2: 0.8622544156791667
# Adjusted R2: 0.846096055159417
# DT
# MSE: 64443433.400655195
# RMSE: 8027.666746985403
# R2: 0.8667683188847667
# Adjusted R2: 0.8511394655409237
# BR
# MSE: 70987589.76829575
# RMSE: 8425.413329225797
# R2: 0.8532387952648652
# Adjusted R2: 0.8360228498818201
# BR
# Binning 0.036 GB of training data: 0.184 s
# Binning 0.004 GB of validation data: 0.007 s
# Fitting gradient boosted rounds:
# [1/100] 1 tree, 31 leaves, max depth = 18, train loss: 173273.01368, val loss: 269473.56637, in 0.032s
# [2/100] 1 tree, 31 leaves, max depth = 17, train loss: 127686.04487, val loss: 198504.97840, in 0.029s
# [3/100] 1 tree, 31 leaves, max depth = 21, train loss: 94019.45324, val loss: 146108.21327, in 0.031s
# [4/100] 1 tree, 31 leaves, max depth = 16, train loss: 69176.55902, val loss: 107428.30475, in 0.030s
# [5/100] 1 tree, 31 leaves, max depth = 19, train loss: 50837.66838, val loss: 78826.60419, in 0.030s
# [6/100] 1 tree, 31 leaves, max depth = 20, train loss: 37303.52241, val loss: 57754.67638, in 0.030s
# [7/100] 1 tree, 31 leaves, max depth = 23, train loss: 27322.60901, val loss: 42192.81804, in 0.030s
# [8/100] 1 tree, 31 leaves, max depth = 23, train loss: 19981.59685, val loss: 30775.10965, in 0.031s
# [9/100] 1 tree, 31 leaves, max depth = 16, train loss: 14585.92755, val loss: 22386.86334, in 0.029s
# [10/100] 1 tree, 31 leaves, max depth = 18, train loss: 10621.53364, val loss: 16247.88016, in 0.028s
# Fit 10 trees in 0.543 s, (310 total leaves)
# Time spent computing histograms: 0.141s
# Time spent finding best splits:  0.015s
# Time spent applying splits:      0.018s
# Time spent predicting:           0.001s
# MSE: 79783083102.63747
# RMSE: 282458.9936656956
# R2: -163.9451887554564
# Adjusted R2: -183.29422153244195
# c1
# MSE: 59938503.5246708
# RMSE: 7741.996094333218
# R2: 0.8760819036677515
# Adjusted R2: 0.8615455881456959
# c2
# MSE: 59938503.5246708
# RMSE: 7741.996094333218
# R2: 0.8760819036677515
# Adjusted R2: 0.8615455881456959
# c3
# MSE: 66626783.623155855
# RMSE: 8162.523116240214
# R2: 0.8622544156791667
# Adjusted R2: 0.846096055159417
# c4
# MSE: 66302108.072045624
# RMSE: 8142.610642296831
# R2: 0.8629256565986643
# Adjusted R2: 0.8468460365541635
# c5
# c6
# RF
# MSE: 33005543.863833535
# RMSE: 5745.045157684449
# R2: 0.9328386380220975
# Adjusted R2: 0.9149812707759643
# DT
# MSE: 42851790.72505767
# RMSE: 6546.127918476514
# R2: 0.9128029933346886
# Adjusted R2: 0.8896183984287913
# BR
# MSE: 31991412.65215091
# RMSE: 5656.095177076753
# R2: 0.93490224387213
# Adjusted R2: 0.9175935636452894
# BR
# Binning 0.041 GB of training data: 0.189 s
# Binning 0.005 GB of validation data: 0.006 s
# Fitting gradient boosted rounds:
# [1/100] 1 tree, 31 leaves, max depth = 18, train loss: 228186.50059, val loss: 532842.46489, in 0.035s
# [2/100] 1 tree, 31 leaves, max depth = 16, train loss: 168426.43773, val loss: 393353.81632, in 0.031s
# [3/100] 1 tree, 31 leaves, max depth = 22, train loss: 124193.20856, val loss: 290092.48449, in 0.033s
# [4/100] 1 tree, 31 leaves, max depth = 22, train loss: 91543.35923, val loss: 213774.72565, in 0.032s
# [5/100] 1 tree, 31 leaves, max depth = 17, train loss: 67402.80875, val loss: 157359.37263, in 0.033s
# [6/100] 1 tree, 31 leaves, max depth = 16, train loss: 49591.87239, val loss: 115666.29466, in 0.031s
# [7/100] 1 tree, 31 leaves, max depth = 23, train loss: 36434.49141, val loss: 84870.33884, in 0.030s
# [8/100] 1 tree, 31 leaves, max depth = 21, train loss: 26718.41587, val loss: 62136.76020, in 0.032s
# [9/100] 1 tree, 31 leaves, max depth = 19, train loss: 19558.37884, val loss: 45398.57988, in 0.033s
# [10/100] 1 tree, 31 leaves, max depth = 13, train loss: 14286.15863, val loss: 33068.67143, in 0.031s
# Fit 10 trees in 0.568 s, (310 total leaves)
# Time spent computing histograms: 0.155s
# Time spent finding best splits:  0.015s
# Time spent applying splits:      0.020s
# Time spent predicting:           0.001s
# MSE: 252030616111.2991
# RMSE: 502026.5093710681
# R2: -511.84473626603403
# Adjusted R2: -648.2037457626275
# c1
# MSE: 31967474.280569088
# RMSE: 5653.978623992939
# R2: 0.9349509548900607
# Adjusted R2: 0.9176552263144451
# c2
# MSE: 31967474.280569088
# RMSE: 5653.978623992939
# R2: 0.9349509548900607
# Adjusted R2: 0.9176552263144451
# c3
# MSE: 31975108.12673534
# RMSE: 5654.653669919612
# R2: 0.9349354211510086
# Adjusted R2: 0.9176355623482089
# c4
# MSE: 31975108.12673534
# RMSE: 5654.653669919612
# R2: 0.9349354211510086
# Adjusted R2: 0.9176355623482089
# c5
# c6
# RF
# MSE: 18766435.37784425
# RMSE: 4332.024397189408
# R2: 0.9346458601489686
# Adjusted R2: 0.8872575993804915
# DT
# MSE: 20302432.947520185
# RMSE: 4505.822116719676
# R2: 0.9292967462678124
# Adjusted R2: 0.8780298451552302
# BR
# MSE: 25246487.173399948
# RMSE: 5024.58825909148
# R2: 0.9120790698788964
# Adjusted R2: 0.8483276384763432
# BR
# Binning 0.043 GB of training data: 0.210 s
# Binning 0.005 GB of validation data: 0.008 s
# Fitting gradient boosted rounds:
# [1/100] 1 tree, 31 leaves, max depth = 19, train loss: 229510.35981, val loss: 207110.53903, in 0.031s
# [2/100] 1 tree, 31 leaves, max depth = 17, train loss: 169340.62570, val loss: 152914.35302, in 0.035s
# [3/100] 1 tree, 31 leaves, max depth = 18, train loss: 124739.95403, val loss: 112674.06520, in 0.032s
# [4/100] 1 tree, 31 leaves, max depth = 22, train loss: 91811.59841, val loss: 83046.12550, in 0.032s
# [5/100] 1 tree, 31 leaves, max depth = 17, train loss: 67523.48292, val loss: 61132.45077, in 0.032s
# [6/100] 1 tree, 31 leaves, max depth = 17, train loss: 49573.43493, val loss: 44974.05937, in 0.032s
# [7/100] 1 tree, 31 leaves, max depth = 23, train loss: 36335.35252, val loss: 33054.64519, in 0.032s
# [8/100] 1 tree, 31 leaves, max depth = 19, train loss: 26569.99287, val loss: 24230.23594, in 0.029s
# [9/100] 1 tree, 31 leaves, max depth = 22, train loss: 19375.76922, val loss: 17737.97623, in 0.032s
# [10/100] 1 tree, 31 leaves, max depth = 17, train loss: 14088.54748, val loss: 12955.73944, in 0.030s
# Fit 10 trees in 0.592 s, (310 total leaves)
# Time spent computing histograms: 0.150s
# Time spent finding best splits:  0.015s
# Time spent applying splits:      0.019s
# Time spent predicting:           0.001s
# MSE: 67196073736.345184
# RMSE: 259222.05488026128
# R2: -233.01042936422542
# Adjusted R2: -402.6912984649785
# c1
# MSE: 16903616.60082438
# RMSE: 4111.400807610999
# R2: 0.9411331293836052
# Adjusted R2: 0.8984487849525937
# c2
# MSE: 15346771.341688871
# RMSE: 3917.4955445652868
# R2: 0.946554845375129
# Adjusted R2: 0.9078017850495254
# c3
# MSE: 18766435.37784425
# RMSE: 4332.024397189408
# R2: 0.9346458601489686
# Adjusted R2: 0.8872575993804915
# c4
# MSE: 16906220.176870134
# RMSE: 4111.717424248672
# R2: 0.9411240624260513
# Adjusted R2: 0.89843314354773
# c5
# c6
# end

# %%
df=pd.DataFrame([pd.Series(mn),pd.Series(Tr),pd.Series(te),pd.Series(r2_value),pd.Series(adj_r2_value),pd.Series(RMSE_value),
                pd.Series(max_i_),pd.Series(max_j_),pd.Series(max_k_),pd.Series(max_l_),pd.Series(times)], 
                index = ["Model Name","Train size","Test size","r2","Adjusted r2","RMSE",
                         "RF weight","DT weight","BR weight value","GBR weight","Time"])
df.head()
# Out:
#                                   0                        1   \
# Model Name   RandomForestRegressor()  DecisionTreeRegressor()
# Train size                       0.7                      0.7
# Test size                        0.3                      0.3
# r2                          0.886025                 0.892218
# Adjusted r2                 0.877448                 0.884107
#
#                              2                            3           4   \
# Model Name   BaggingRegressor()  GradientBoostingRegressor()  weight 1()
# Train size                  0.7                          0.7         0.7
# Test size                   0.3                          0.3         0.3
# r2                     0.877796                  -139.188039    0.897912
# Adjusted r2              0.8686                  -149.737645    0.890229
#
#                      5           6           7                        8   \
# Model Name   weight 2()  weight 3()  weight 4()  RandomForestRegressor()
# Train size          0.7         0.7         0.7                      0.8
# Test size           0.3         0.3         0.3                      0.2
# r2             0.897912    0.886025    0.886066                 0.862254
# Adjusted r2    0.890229    0.877448    0.877492                 0.846096
#
#                                   9   ...          22          23  \
# Model Name   DecisionTreeRegressor()  ...  weight 3()  weight 4()
# Train size                       0.8  ...         0.9         0.9
# Test size                        0.2  ...         0.1         0.1
# r2                          0.866768  ...    0.934935    0.934935
# Adjusted r2                 0.851139  ...    0.917636    0.917636
#
#                                   24                       25  \
# Model Name   RandomForestRegressor()  DecisionTreeRegressor()
# Train size                      0.95                     0.95
# Test size                       0.05                     0.05
# r2                          0.934646                 0.929297
# Adjusted r2                 0.887258                  0.87803
#
#                              26                           27          28  \
# Model Name   BaggingRegressor()  GradientBoostingRegressor()  weight 1()
# Train size                 0.95                         0.95        0.95
# Test size                  0.05                         0.05        0.05
# r2                     0.912079                  -233.010429    0.941133
# Adjusted r2            0.848328                  -402.691298    0.898449
#
#                      29          30          31
# Model Name   weight 2()  weight 3()  weight 4()
# Train size         0.95        0.95        0.95
# Test size          0.05        0.05        0.05
# r2             0.946555    0.934646    0.941124
# Adjusted r2    0.907802    0.887258    0.898433
#
# [5 rows x 32 columns]

# %%
df1=df.T
df1.head()
# Out:
#                     Model Name Train size Test size          r2 Adjusted r2  \
# 0      RandomForestRegressor()        0.7       0.3    0.886025    0.877448
# 1      DecisionTreeRegressor()        0.7       0.3    0.892218    0.884107
# 2           BaggingRegressor()        0.7       0.3    0.877796      0.8686
# 3  GradientBoostingRegressor()        0.7       0.3 -139.188039 -149.737645
# 4                   weight 1()        0.7       0.3    0.897912    0.890229
#
#             RMSE RF weight DT weight BR weight value GBR weight       Time
# 0    6768.096565         0         0               0          0  84.802701
# 1    6581.654582         0         0               0          0   1.613518
# 2    7008.146996         0         0               0          0   4.898724
# 3  237365.044706         0         0               0          0   0.604006
# 4    6405.449524        28        60              12          0        0.0

# %%
df1.to_csv("Table.csv")

# %%
df1
# Out:
#                      Model Name Train size Test size          r2 Adjusted r2  \
# 0       RandomForestRegressor()        0.7       0.3    0.886025    0.877448
# 1       DecisionTreeRegressor()        0.7       0.3    0.892218    0.884107
# 2            BaggingRegressor()        0.7       0.3    0.877796      0.8686
# 3   GradientBoostingRegressor()        0.7       0.3 -139.188039 -149.737645
# 4                    weight 1()        0.7       0.3    0.897912    0.890229
# 5                    weight 2()        0.7       0.3    0.897912    0.890229
# 6                    weight 3()        0.7       0.3    0.886025    0.877448
# 7                    weight 4()        0.7       0.3    0.886066    0.877492
# 8       RandomForestRegressor()        0.8       0.2    0.862254    0.846096
# 9       DecisionTreeRegressor()        0.8       0.2    0.866768    0.851139
# 10           BaggingRegressor()        0.8       0.2    0.853239    0.836023
# 11  GradientBoostingRegressor()        0.8       0.2 -163.945189 -183.294222
# 12                   weight 1()        0.8       0.2    0.876082    0.861546
# 13                   weight 2()        0.8       0.2    0.876082    0.861546
# 14                   weight 3()        0.8       0.2    0.862254    0.846096
# 15                   weight 4()        0.8       0.2    0.862926    0.846846
# 16      RandomForestRegressor()        0.9       0.1    0.932839    0.914981
# 17      DecisionTreeRegressor()        0.9       0.1    0.912803    0.889618
# 18           BaggingRegressor()        0.9       0.1    0.934902    0.917594
# 19  GradientBoostingRegressor()        0.9       0.1 -511.844736 -648.203746
# 20                   weight 1()        0.9       0.1    0.934951    0.917655
# 21                   weight 2()        0.9       0.1    0.934951    0.917655
# 22                   weight 3()        0.9       0.1    0.934935    0.917636
# 23                   weight 4()        0.9       0.1    0.934935    0.917636
# 24      RandomForestRegressor()       0.95      0.05    0.934646    0.887258
# 25      DecisionTreeRegressor()       0.95      0.05    0.929297     0.87803
# 26           BaggingRegressor()       0.95      0.05    0.912079    0.848328
# 27  GradientBoostingRegressor()       0.95      0.05 -233.010429 -402.691298
# 28                   weight 1()       0.95      0.05    0.941133    0.898449
# 29                   weight 2()       0.95      0.05    0.946555    0.907802
# 30                   weight 3()       0.95      0.05    0.934646    0.887258
# 31                   weight 4()       0.95      0.05    0.941124    0.898433
#
#              RMSE RF weight DT weight BR weight value GBR weight        Time
# 0     6768.096565         0         0               0          0   84.802701
# 1     6581.654582         0         0               0          0    1.613518
# 2     7008.146996         0         0               0          0    4.898724
# 3   237365.044706         0         0               0          0    0.604006
# 4     6405.449524        28        60              12          0         0.0
# 5     6405.449524        28        60              12          0         0.0
# 6     6768.096565       100         0               0          0         0.0
# 7     6766.884799       108         0              -8          0         0.0
# 8     8162.523116         0         0               0          0  106.325064
# 9     8027.666747         0         0               0          0    1.978331
# 10    8425.413329         0         0               0          0    5.772634
# 11  282458.993666         0         0               0          0    0.544914
# 12    7741.996094         7        60              33          0         0.0
# 13    7741.996094         7        60              33          0         0.0
# 14    8162.523116       100         0               0          0         0.0
# 15    8142.610642       136         0             -36          0         0.0
# 16    5745.045158         0         0               0          0  127.107208
# 17    6546.127918         0         0               0          0    2.325367
# 18    5656.095177         0         0               0          0    6.019999
# 19  502026.509371         0         0               0          0    0.570025
# 20    5653.978624         9         3              88          0         0.0
# 21    5653.978624         9         3              88          0         0.0
# 22     5654.65367        11         0              89          0         0.0
# 23     5654.65367        11         0              89          0         0.0
# 24    4332.024397         0         0               0          0  137.427253
# 25    4505.822117         0         0               0          0    2.357306
# 26    5024.588259         0         0               0          0    6.460227
# 27   259222.05488         0         0               0          0    0.593173
# 28    4111.400808        57        43               0          0         0.0
# 29    3917.495545       143        39             -82          0         0.0
# 30    4332.024397       100         0               0          0         0.0
# 31    4111.717424       189         0             -89          0         0.0
