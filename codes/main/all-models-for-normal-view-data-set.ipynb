# %%
# Version 8: table weight rename
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
import time
import glob
g=glob.glob('../input/calfl1016combrts/sparce-all-rts-cal-fl-withfareclass.csv')
r2_value=[]
adj_r2_value=[]
RMSE_value=[]
#route_name=[]
Tr=[]
te=[]
mn=[]
max_i_=[]
max_j_=[]
max_k_=[]
max_l_=[]
times=[]

# %%
g
# Out:
# ['../input/calfl1016combrts/sparce-all-rts-cal-fl-withfareclass.csv']

# %%
#descision tree
from sklearn.tree import DecisionTreeRegressor
def dt(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,o,k):
    start = time.time()
    model = DecisionTreeRegressor().fit(X_train, y_train)
    stop = time.time()
    if o==0:
        predictions = model.predict(X_test)
        mse = mean_squared_error(y_test, predictions)

        print("MSE:", mse)

        rmse = np.sqrt(mse)

        print("RMSE:", rmse)

        r2 = r2_score(y_test, predictions)

        print("R2:", r2)
        ar2=1-(1-r2)*((len(X_test)-1)/(len(X_test)-X_test.shape[1]-1))
        print("Adjusted R2:",ar2)
        Tr.append(1-k)#train
        te.append(k)#test
        r2_value.append(r2)
        adj_r2_value.append(ar2)
        RMSE_value.append(rmse)
        #route_name.append(rt[0])
        mn.append("DecisionTreeRegressor()")
        max_i_.append(0)
        max_j_.append(0)
        max_k_.append(0)
        max_l_.append(0)
        times.append(stop-start)
    return model

# %%
#Random Forest
from sklearn.ensemble import RandomForestRegressor
def rf(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,o,k):
    start = time.time()
    model = RandomForestRegressor().fit(X_train, y_train)
    stop = time.time()
    if o==0:
        predictions = model.predict(X_test)
        mse = mean_squared_error(y_test, predictions)

        print("MSE:", mse)

        rmse = np.sqrt(mse)

        print("RMSE:", rmse)

        r2 = r2_score(y_test, predictions)

        print("R2:", r2)
        ar2=1-(1-r2)*((len(X_test)-1)/(len(X_test)-X_test.shape[1]-1))
        print("Adjusted R2:",ar2)
        Tr.append(1-k)#train
        te.append(k)#test
        r2_value.append(r2)
        adj_r2_value.append(ar2)
        RMSE_value.append(rmse)
        #route_name.append(rt[0])
        mn.append("RandomForestRegressor()")
        max_i_.append(0)
        max_j_.append(0)
        max_k_.append(0)
        max_l_.append(0)
        times.append(stop-start)
    return model

# %%
#Bagging Regressor
from sklearn.ensemble import BaggingRegressor
def br(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,o,k):
    start = time.time()
    model = BaggingRegressor().fit(X_train, y_train)
    stop = time.time()
    if o==0:
        predictions = model.predict(X_test)
        mse = mean_squared_error(y_test, predictions)

        print("MSE:", mse)

        rmse = np.sqrt(mse)

        print("RMSE:", rmse)

        r2 = r2_score(y_test, predictions)

        print("R2:", r2)
        ar2=1-(1-r2)*((len(X_test)-1)/(len(X_test)-X_test.shape[1]-1))
        print("Adjusted R2:",ar2)
        Tr.append(1-k)#train
        te.append(k)#test
        r2_value.append(r2)
        adj_r2_value.append(ar2)
        RMSE_value.append(rmse)
        #route_name.append(rt[0])
        mn.append("BaggingRegressor()")
        max_i_.append(0)
        max_j_.append(0)
        max_k_.append(0)
        max_l_.append(0)
        times.append(stop-start)
    return model

# %%
#
from sklearn.experimental import enable_hist_gradient_boosting 
from sklearn.ensemble import HistGradientBoostingRegressor

def gbr(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,o,k):
    params = {
              #'n_trees_per_iteration_':2,
          #'max_depth': 4,
          #'min_samples_split': 5,
          'learning_rate': 0.3,#[0.1,0.15,0.2,0.175,0.225],
          'loss': 'poisson',#[‘least_squares’, ‘least_absolute_deviation’, ‘poisson’],
            'verbose':2}
    start = time.time()
    model = HistGradientBoostingRegressor(**params).fit(X_train, y_train)
    stop = time.time()
    if o==0:
        predictions = model.predict(X_test)
        mse = mean_squared_error(y_test, predictions)

        print("MSE:", mse)

        rmse = np.sqrt(mse)

        print("RMSE:", rmse)

        r2 = r2_score(y_test, predictions)

        print("R2:", r2)
        ar2=1-(1-r2)*((len(X_test)-1)/(len(X_test)-X_test.shape[1]-1))
        print("Adjusted R2:",ar2)
        Tr.append(1-k)#train
        te.append(k)#test
        r2_value.append(r2)
        adj_r2_value.append(ar2)
        RMSE_value.append(rmse)
        #route_name.append(rt[0])
        mn.append("GradientBoostingRegressor()")
        max_i_.append(0)
        max_j_.append(0)
        max_k_.append(0)
        max_l_.append(0)
        times.append(stop-start)
    return model

# %%
#positive weight DT
def c1(model1,model2,model3,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,tst):
    
    #RF
    #model1=rf(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,1)
    predictions1 = model1.predict(X_test)
    #DT
    #model2=dt(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,1) 
    predictions2 = model2.predict(X_test)
    #BR
    #model3=br(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,1)
    predictions3 = model3.predict(X_test)
    
    
    max_r2=0
    mi=0
    mj=0
    mk=0
    for i in range(0,101):
        for j in range(0,101):
            for k in range(0,101):
                if((i+j+k)==100):
                    #print(i," ",j," ",k)
                    pred=(i/100)*predictions1+(j/100)*predictions2+(k/100)*predictions3
                    r2 = r2_score(y_test, pred)
                    if(r2>max_r2):
                        max_r2=r2
                        mi=i
                        mj=j
                        mk=k
    
    
    predictions = (mi/100)*predictions1+(mj/100)*predictions2+(mk/100)*predictions3
    mse = mean_squared_error(y_test, predictions)

    print("MSE:", mse)

    rmse = np.sqrt(mse)

    print("RMSE:", rmse)

    r2 = r2_score(y_test, predictions)

    print("R2:", r2)
    ar2=1-(1-r2)*((len(X_test)-1)/(len(X_test)-X_test.shape[1]-1))
    print("Adjusted R2:",ar2)
    Tr.append(1-tst)#train
    te.append(tst)#test
    r2_value.append(r2)
    adj_r2_value.append(ar2)
    RMSE_value.append(rmse)
    #route_name.append(rt[0])
    mn.append("weight 1()")
    max_i_.append(mi)
    max_j_.append(mj)
    max_k_.append(mk)
    max_l_.append(0)
    times.append(0)
    return

# %%
#negative weight DT
def c2(model1,model2,model3,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,tst):
    
    #RF
    #model1=rf(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,1)
    predictions1 = model1.predict(X_test)
    #DT
    #model2=dt(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,1) 
    predictions2 = model2.predict(X_test)
    #BR
    #model3=br(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,1)
    predictions3 = model3.predict(X_test)
    
    
    max_r2=0
    mi=0
    mj=0
    mk=0
    for i in range(-100,301):
        for j in range(-100,301):
            for k in range(-100,301):
                if((i+j+k)==100):
                    #print(i," ",j," ",k)
                    pred=(i/100)*predictions1+(j/100)*predictions2+(k/100)*predictions3
                    r2 = r2_score(y_test, pred)
                    if(r2>max_r2):
                        max_r2=r2
                        mi=i
                        mj=j
                        mk=k
    
    
    predictions = (mi/100)*predictions1+(mj/100)*predictions2+(mk/100)*predictions3
    mse = mean_squared_error(y_test, predictions)

    print("MSE:", mse)

    rmse = np.sqrt(mse)

    print("RMSE:", rmse)

    r2 = r2_score(y_test, predictions)

    print("R2:", r2)
    ar2=1-(1-r2)*((len(X_test)-1)/(len(X_test)-X_test.shape[1]-1))
    print("Adjusted R2:",ar2)
    Tr.append(1-tst)#train
    te.append(tst)#test
    r2_value.append(r2)
    adj_r2_value.append(ar2)
    RMSE_value.append(rmse)
    #route_name.append(rt[0])
    mn.append("weight 2()")
    max_i_.append(mi)
    max_j_.append(mj)
    max_k_.append(mk)
    max_l_.append(0)
    times.append(0)
    return

# %%
#positive weight GBR
def c3(model1,model2,model3,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,tst):
    
    #RF
    #model1=rf(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,1)
    predictions1 = model1.predict(X_test)
    #DT
    #model2=dt(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,1) 
    predictions2 = model2.predict(X_test)
    #BR
    #model3=br(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,1)
    predictions3 = model3.predict(X_test)
    
    
    max_r2=0
    mi=0
    mj=0
    mk=0
    for i in range(0,101):
        for j in range(0,101):
            for k in range(0,101):
                if((i+j+k)==100):
                    #print(i," ",j," ",k)
                    pred=(i/100)*predictions1+(j/100)*predictions2+(k/100)*predictions3
                    r2 = r2_score(y_test, pred)
                    if(r2>max_r2):
                        max_r2=r2
                        mi=i
                        mj=j
                        mk=k
    
    
    predictions = (mi/100)*predictions1+(mj/100)*predictions2+(mk/100)*predictions3
    mse = mean_squared_error(y_test, predictions)

    print("MSE:", mse)

    rmse = np.sqrt(mse)

    print("RMSE:", rmse)

    r2 = r2_score(y_test, predictions)

    print("R2:", r2)
    ar2=1-(1-r2)*((len(X_test)-1)/(len(X_test)-X_test.shape[1]-1))
    print("Adjusted R2:",ar2)
    Tr.append(1-tst)#train
    te.append(tst)#test
    r2_value.append(r2)
    adj_r2_value.append(ar2)
    RMSE_value.append(rmse)
    #route_name.append(rt[0])
    mn.append("weight 3()")
    max_i_.append(mi)
    max_j_.append(0)
    max_k_.append(mk)
    max_l_.append(mj)
    times.append(0)
    return

# %%
#negative weight GBR
def c4(model1,model2,model3,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,tst):
    
    #RF
    #model1=rf(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,1)
    predictions1 = model1.predict(X_test)
    #DT
    #model2=dt(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,1) 
    predictions2 = model2.predict(X_test)
    #BR
    #model3=br(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,1)
    predictions3 = model3.predict(X_test)
    
    
    max_r2=0
    mi=0
    mj=0
    mk=0
    for i in range(-100,301):
        for j in range(-100,301):
            for k in range(-100,301):
                if((i+j+k)==100):
                    #print(i," ",j," ",k)
                    pred=(i/100)*predictions1+(j/100)*predictions2+(k/100)*predictions3
                    r2 = r2_score(y_test, pred)
                    if(r2>max_r2):
                        max_r2=r2
                        mi=i
                        mj=j
                        mk=k
    
    
    predictions = (mi/100)*predictions1+(mj/100)*predictions2+(mk/100)*predictions3
    mse = mean_squared_error(y_test, predictions)

    print("MSE:", mse)

    rmse = np.sqrt(mse)

    print("RMSE:", rmse)

    r2 = r2_score(y_test, predictions)

    print("R2:", r2)
    ar2=1-(1-r2)*((len(X_test)-1)/(len(X_test)-X_test.shape[1]-1))
    print("Adjusted R2:",ar2)
    Tr.append(1-tst)#train
    te.append(tst)#test
    r2_value.append(r2)
    adj_r2_value.append(ar2)
    RMSE_value.append(rmse)
    #route_name.append(rt[0])
    mn.append("weight 4()")
    max_i_.append(mi)
    max_j_.append(0)
    max_k_.append(mk)
    max_l_.append(mj)
    times.append(0)
    return

# %%
import pickle
print("begin")
F=1
for file in g:
    print(F)
    F=F+1
    df=pd.read_csv(file)
    print(df.columns)
    y = df['MktFare'].values
    X= df.drop(['MktFare','Unnamed: 0'],axis=1).values
    y=y.astype(float)
    
    # Train the model
    for k in [0.3,0.2,0.1,0.05]:
        
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=k, random_state=0)
        #RF
        print("RF")
        model1=rf(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,0,k)
        #DT
        print("DT")
        model2=dt(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,0,k) 
        #BR
        print("BR")
        model3=br(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,0,k)
        
        #GBR
        print("BR")
        model4=gbr(X_train, y_train,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,0,k)
        
        #positive weight DT
        print("c1")
        c1(model1,model2,model3,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,k)
        
        #negative weight DT
        print("c2")
        c2(model1,model2,model3,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,k)
        
        #positive weight GBR
        print("c3")
        c3(model1,model4,model3,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,k)
        
        #negative weight GBR
        print("c4")
        c4(model1,model4,model3,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,k)
        
        print("c5")
        #c5(model1,model2,model3,model4,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,k)
        
        print("c6")
        #c6(model1,model2,model3,model4,Tr,te,r2_value,adj_r2_value,RMSE_value,mn,max_i_,max_j_,max_k_,max_l_,k)
        
        #model saving
        filename = 'RFmodel'+str(k)+'.pkl'
        pickle.dump(model1, open(filename, 'wb'))
        
        filename = 'DTmodel'+str(k)+'.pkl'
        pickle.dump(model2, open(filename, 'wb'))
        
        filename = 'BRmodel'+str(k)+'.pkl'
        pickle.dump(model3, open(filename, 'wb'))
        
        filename = 'GBRmodel'+str(k)+'.pkl'
        pickle.dump(model4, open(filename, 'wb'))
        
        
        
 
    

print("end")
# Out:
# begin
# 1
# Index(['Unnamed: 0', 'MktCoupons', 'Year', 'Quarter', 'BulkFare', 'Passengers',
#        'MktFare', 'Pandemic', 'RPCarrier_9E', 'RPCarrier_AA', 'RPCarrier_AS',
#        'RPCarrier_B6', 'RPCarrier_CP', 'RPCarrier_DL', 'RPCarrier_EV',
#        'RPCarrier_F9', 'RPCarrier_G7', 'RPCarrier_HA', 'RPCarrier_MQ',
#        'RPCarrier_NK', 'RPCarrier_OH', 'RPCarrier_OO', 'RPCarrier_QX',
#        'RPCarrier_SY', 'RPCarrier_UA', 'RPCarrier_VX', 'RPCarrier_WN',
#        'RPCarrier_YV', 'RPCarrier_YX', 'route_BUR-SFO', 'route_FLL-LAX',
#        'route_FLL-SAN', 'route_FLL-SFO', 'route_LAX-FLL', 'route_LAX-MCO',
#        'route_LAX-MIA', 'route_LAX-OAK', 'route_LAX-SFO', 'route_LAX-SJC',
#        'route_LAX-SMF', 'route_LAX-TPA', 'route_MCO-LAX', 'route_MCO-SAN',
#        'route_MCO-SFO', 'route_MCO-SMF', 'route_MIA-LAX', 'route_MIA-SFO',
#        'route_OAK-LAX', 'route_PSP-SFO', 'route_SAN-MCO', 'route_SAN-SFO',
#        'route_SAN-SJC', 'route_SAN-SMF', 'route_SAN-TPA', 'route_SFO-BUR',
#        'route_SFO-FLL', 'route_SFO-LAX', 'route_SFO-MCO', 'route_SFO-MIA',
#        'route_SFO-PSP', 'route_SFO-SAN', 'route_SFO-SNA', 'route_SFO-TPA',
#        'route_SJC-LAX', 'route_SJC-SAN', 'route_SJC-SNA', 'route_SMF-LAX',
#        'route_SMF-MCO', 'route_SMF-SAN', 'route_SNA-SFO', 'route_SNA-SJC',
#        'route_TPA-LAX', 'route_TPA-SAN', 'route_TPA-SFO', 'FareClass_Others',
#        'FareClass_Restricted Business Class',
#        'FareClass_Restricted Coach Class', 'FareClass_Restricted First Class',
#        'FareClass_Unrestricted Business Class',
#        'FareClass_Unrestricted Coach Class',
#        'FareClass_Unrestricted First Class'],
#       dtype='object')
# RF
# MSE: 37988.67953021374
# RMSE: 194.9068483409799
# R2: 0.3583452657707701
# Adjusted R2: 0.3581419392536481
# DT
# MSE: 39015.78484610149
# RMSE: 197.52413737592045
# R2: 0.3409967557240542
# Adjusted R2: 0.34078793183905376
# BR
# MSE: 38374.51838985997
# RMSE: 195.89415098430064
# R2: 0.35182818399790383
# Adjusted R2: 0.3516227923584224
# BR
# Binning 0.331 GB of training data: 1.556 s
# Binning 0.037 GB of validation data: 0.055 s
# Fitting gradient boosted rounds:
# [1/100] 1 tree, 31 leaves, max depth = 12, train loss: 60.24745, val loss: 62.25418, in 0.239s
# [2/100] 1 tree, 31 leaves, max depth = 19, train loss: 54.84387, val loss: 56.78159, in 0.256s
# [3/100] 1 tree, 31 leaves, max depth = 18, train loss: 51.80492, val loss: 53.65761, in 0.241s
# [4/100] 1 tree, 31 leaves, max depth = 23, train loss: 50.09331, val loss: 51.89760, in 0.246s
# [5/100] 1 tree, 31 leaves, max depth = 13, train loss: 48.82386, val loss: 50.60848, in 0.241s
# [6/100] 1 tree, 31 leaves, max depth = 30, train loss: 47.67274, val loss: 49.44546, in 0.254s
# [7/100] 1 tree, 31 leaves, max depth = 22, train loss: 47.06322, val loss: 48.84766, in 0.229s
# [8/100] 1 tree, 31 leaves, max depth = 20, train loss: 46.37678, val loss: 48.17749, in 0.233s
# [9/100] 1 tree, 31 leaves, max depth = 13, train loss: 46.02153, val loss: 47.83364, in 0.227s
# [10/100] 1 tree, 31 leaves, max depth = 25, train loss: 45.55424, val loss: 47.35831, in 0.250s
# [11/100] 1 tree, 31 leaves, max depth = 21, train loss: 45.19305, val loss: 46.96336, in 0.230s
100] 1 tree, 31 leaves, max depth = 10, train loss: 41.87516, val loss: 43.99178, in 0.156s
# [44/100] 1 tree, 31 leaves, max depth = 13, train loss: 41.84918, val loss: 43.96762, in 0.180s
# [45/100] 1 tree, 31 leaves, max depth = 9, train loss: 41.83216, val loss: 43.96345, in 0.132s
# [46/100] 1 tree, 31 leaves, max depth = 10, train loss: 41.80250, val loss: 43.92710, in 0.149s
# [47/100] 1 tree, 31 leaves, max depth = 10, train loss: 41.78802, val loss: 43.91384, in 0.149s
# [48/100] 1 tree, 31 leaves, max depth = 10, train loss: 41.75517, val loss: 43.89063, in 0.179s
# [49/100] 1 tree, 31 leaves, max depth = 9, train loss: 41.73547, val loss: 43.87941, in 0.132s
# [50/100] 1 tree, 31 leaves, max depth = 13, train loss: 41.71173, val loss: 43.86271, in 0.173s
# [51/100] 1 tree, 31 leaves, max depth = 13, train loss: 41.69548, val loss: 43.84776, in 0.165s
# [52/100] 1 tree, 31 leaves, max depth = 8, train loss: 41.67704, val loss: 43.84175, in 0.135s
# [53/100] 1 tree, 31 leaves, max depth = 12, train loss: 41.65961, val loss: 43.82870, in 0.143s
# [54/100] 1 tree, 31 leaves, max depth = 9, train loss: 41.61739, val loss: 43.79135, in 0.196s
# [55/100] 1 tree, 31 leaves, max depth = 10, train loss: 41.60298, val loss: 43.78322, in 0.134s
# [56/100] 1 tree, 31 leaves, max depth = 11, train loss: 41.56537, val loss: 43.76271, in 0.140s
# [57/100] 1 tree, 31 leaves, max depth = 9, train loss: 41.53258, val loss: 43.74041, in 0.150s
# [58/100] 1 tree, 31 leaves, max depth = 12, train loss: 41.52043, val loss: 43.72775, in 0.143s
# [59/100] 1 tree, 31 leaves, max depth = 11, train loss: 41.50998, val loss: 43.72009, in 0.153s
# [60/100] 1 tree, 31 leaves, max depth = 10, train loss: 41.42021, val loss: 43.73634, in 0.143s
# [61/100] 1 tree, 31 leaves, max depth = 11, train loss: 41.38713, val loss: 43.72649, in 0.145s
# [62/100] 1 tree, 31 leaves, max depth = 8, train loss: 41.37812, val loss: 43.71546, in 0.155s
# [63/100] 1 tree, 31 leaves, max depth = 13, train loss: 41.36853, val loss: 43.71202, in 0.151s
# [64/100] 1 tree, 31 leaves, max depth = 10, train loss: 41.33050, val loss: 43.71809, in 0.155s
# [65/100] 1 tree, 31 leaves, max depth = 13, train loss: 41.30538, val loss: 43.71567, in 0.144s
# [66/100] 1 tree, 31 leaves, max depth = 12, train loss: 41.23946, val loss: 43.68598, in 0.157s
# [67/100] 1 tree, 31 leaves, max depth = 10, train loss: 41.22699, val loss: 43.68049, in 0.139s
# [68/100] 1 tree, 31 leaves, max depth = 13, train loss: 41.21036, val loss: 43.66239, in 0.138s
# [69/100] 1 tree, 31 leaves, max depth = 9, train loss: 41.18499, val loss: 43.65924, in 0.163s
# [70/100] 1 tree, 31 leaves, max depth = 9, train loss: 41.17360, val loss: 43.64981, in 0.162s
# [71/100] 1 tree, 31 leaves, max depth = 12, train loss: 41.14062, val loss: 43.64568, in 0.165s
# [72/100] 1 tree, 31 leaves, max depth = 11, train loss: 41.11768, val loss: 43.63203, in 0.168s
# [73/100] 1 tree, 31 leaves, max depth = 11, train loss: 41.10879, val loss: 43.62542, in 0.144s
# [74/100] 1 tree, 31 leaves, max depth = 11, train loss: 41.06868, val loss: 43.59976, in 0.161s
# [75/100] 1 tree, 31 leaves, max depth = 13, train loss: 41.06049, val loss: 43.59362, in 0.158s
# [76/100] 1 tree, 31 leaves, max depth = 11, train loss: 41.04412, val loss: 43.58280, in 0.166s
# [77/100] 1 tree, 31 leaves, max depth = 13, train loss: 41.03317, val loss: 43.58821, in 0.155s
# [78/100] 1 tree, 31 leaves, max depth = 11, train loss: 41.01985, val loss: 43.57879, in 0.140s
# [79/100] 1 tree, 31 leaves, max depth = 12, train loss: 41.00950, val loss: 43.57733, in 0.126s
# [80/100] 1 tree, 31 leaves, max depth = 12, train loss: 40.99860, val loss: 43.57438, in 0.135s
# [81/100] 1 tree, 31 leaves, max depth = 9, train loss: 40.98740, val loss: 43.56860, in 0.154s
# [82/100] 1 tree, 31 leaves, max depth = 12, train loss: 40.95765, val loss: 43.55257, in 0.127s
# [83/100] 1 tree, 31 leaves, max depth = 10, train loss: 40.93196, val loss: 43.54479, in 0.213s
# [84/100] 1 tree, 31 leaves, max depth = 13, train loss: 40.90948, val loss: 43.54054, in 0.187s
# [85/100] 1 tree, 31 leaves, max depth = 12, train loss: 40.90286, val loss: 43.52922, in 0.435s
# [86/100] 1 tree, 31 leaves, max depth = 9, train loss: 40.89158, val loss: 43.52804, in 0.581s
# [87/100] 1 tree, 31 leaves, max depth = 9, train loss: 40.88277, val loss: 43.52354, in 0.183s
# [88/100] 1 tree, 31 leaves, max depth = 9, train loss: 40.87095, val loss: 43.52858, in 0.146s
# [89/100] 1 tree, 31 leaves, max depth = 10, train loss: 40.86204, val loss: 43.52081, in 0.132s
# [90/100] 1 tree, 31 leaves, max depth = 11, train loss: 40.84249, val loss: 43.51052, in 0.136s
# [91/100] 1 tree, 31 leaves, max depth = 9, train loss: 40.82947, val loss: 43.50088, in 0.156s
# [92/100] 1 tree, 31 leaves, max depth = 16, train loss: 40.82337, val loss: 43.50268, in 0.128s
# [93/100] 1 tree, 31 leaves, max depth = 10, train loss: 40.81835, val loss: 43.49759, in 0.141s
# [94/100] 1 tree, 31 leaves, max depth = 9, train loss: 40.81349, val loss: 43.49395, in 0.134s
# [95/100] 1 tree, 31 leaves, max depth = 10, train loss: 40.80706, val loss: 43.48511, in 0.138s
# [96/100] 1 tree, 31 leaves, max depth = 10, train loss: 40.80097, val loss: 43.48231, in 0.141s
# [97/100] 1 tree, 31 leaves, max depth = 13, train loss: 40.79487, val loss: 43.48873, in 0.149s
# [98/100] 1 tree, 31 leaves, max depth = 11, train loss: 40.78989, val loss: 43.48657, in 0.145s
# [99/100] 1 tree, 31 leaves, max depth = 9, train loss: 40.78460, val loss: 43.48085, in 0.211s
# [100/100] 1 tree, 31 leaves, max depth = 12, train loss: 40.77704, val loss: 43.47790, in 0.139s
# Fit 100 trees in 19.938 s, (3100 total leaves)
# Time spent computing histograms: 5.335s
# Time spent finding best splits:  0.241s
# Time spent applying splits:      0.770s
# Time spent predicting:           0.189s
# MSE: 36816.150611632576
# RMSE: 191.87535175637484
# R2: 0.37815007975568105
# Adjusted R2: 0.3779530289560673
# c1
# MSE: 37988.67953021374
# RMSE: 194.9068483409799
# R2: 0.3583452657707701
# Adjusted R2: 0.3581419392536481
# c2
# MSE: 37943.13104751176
# RMSE: 194.7899664959973
# R2: 0.3591146107420644
# Adjusted R2: 0.35891152801373594
# c3
# MSE: 36666.441118983654
# RMSE: 191.48483260818244
# R2: 0.3806787753014379
# Adjusted R2: 0.38048252579078956
# c4
# MSE: 36663.19033332339
# RMSE: 191.4763440567095
# R2: 0.3807336832907302
# Adjusted R2: 0.380537451179237
# c5
# c6
# RF
# MSE: 39359.3326467209
# RMSE: 198.3918663824727
# R2: 0.35003644440515025
# Adjusted R2: 0.3497274557249881
# DT
# MSE: 40201.196161700376
# RMSE: 200.50235949160393
# R2: 0.3361342624643895
# Adjusted R2: 0.33581866477236466
# BR
# MSE: 39349.87249683591
# RMSE: 198.36802286869704
# R2: 0.35019266536323657
# Adjusted R2: 0.3498837509495579
# BR
# Binning 0.378 GB of training data: 1.639 s
# Binning 0.042 GB of validation data: 0.100 s
# Fitting gradient boosted rounds:
# [1/100] 1 tree, 31 leaves, max depth = 12, train loss: 60.09326, val loss: 62.18974, in 0.249s
# [2/100] 1 tree, 31 leaves, max depth = 19, train loss: 54.83423, val loss: 56.71358, in 0.279s
# [3/100] 1 tree, 31 leaves, max depth = 17, train loss: 51.76954, val loss: 53.53858, in 0.264s
# [4/100] 1 tree, 31 leaves, max depth = 24, train loss: 49.85460, val loss: 51.53693, in 0.274s
# [5/100] 1 tree, 31 leaves, max depth = 11, train loss: 48.47603, val loss: 50.14901, in 0.259s
# [6/100] 1 tree, 31 leaves, max depth = 28, train loss: 47.32915, val loss: 48.96062, in 0.269s
100] 1 tree, 31 leaves, max depth = 10, train loss: 41.00230, val loss: 43.32203, in 0.148s
# [84/100] 1 tree, 31 leaves, max depth = 8, train loss: 40.99205, val loss: 43.31819, in 0.166s
# [85/100] 1 tree, 31 leaves, max depth = 11, train loss: 40.98412, val loss: 43.31236, in 0.156s
# [86/100] 1 tree, 31 leaves, max depth = 13, train loss: 40.95860, val loss: 43.28408, in 0.155s
# [87/100] 1 tree, 31 leaves, max depth = 10, train loss: 40.94257, val loss: 43.26898, in 0.164s
# [88/100] 1 tree, 31 leaves, max depth = 9, train loss: 40.91516, val loss: 43.21548, in 0.171s
# [89/100] 1 tree, 31 leaves, max depth = 9, train loss: 40.87487, val loss: 43.18545, in 0.205s
# [90/100] 1 tree, 31 leaves, max depth = 16, train loss: 40.84040, val loss: 43.16034, in 0.192s
# [91/100] 1 tree, 31 leaves, max depth = 11, train loss: 40.81850, val loss: 43.14285, in 0.223s
# [92/100] 1 tree, 31 leaves, max depth = 13, train loss: 40.81348, val loss: 43.13932, in 0.149s
# [93/100] 1 tree, 31 leaves, max depth = 11, train loss: 40.80868, val loss: 43.13518, in 0.161s
# [94/100] 1 tree, 31 leaves, max depth = 9, train loss: 40.80095, val loss: 43.12805, in 0.303s
# [95/100] 1 tree, 31 leaves, max depth = 14, train loss: 40.79558, val loss: 43.12382, in 0.147s
# [96/100] 1 tree, 31 leaves, max depth = 10, train loss: 40.79187, val loss: 43.12006, in 0.160s
# [97/100] 1 tree, 31 leaves, max depth = 9, train loss: 40.78763, val loss: 43.11719, in 0.153s
# [98/100] 1 tree, 31 leaves, max depth = 10, train loss: 40.77967, val loss: 43.11347, in 0.169s
# [99/100] 1 tree, 31 leaves, max depth = 12, train loss: 40.76757, val loss: 43.11667, in 0.172s
# [100/100] 1 tree, 31 leaves, max depth = 12, train loss: 40.76262, val loss: 43.11065, in 0.158s
# Fit 100 trees in 22.200 s, (3100 total leaves)
# Time spent computing histograms: 5.993s
# Time spent finding best splits:  0.225s
# Time spent applying splits:      0.966s
# Time spent predicting:           0.236s
# MSE: 38085.23281490649
# RMSE: 195.15438200282998
# R2: 0.37107639608069987
# Adjusted R2: 0.3707774096642692
# c1
# MSE: 39277.93075513605
# RMSE: 198.18660589236612
# R2: 0.3513806811929415
# Adjusted R2: 0.35107233155468764
# c2
# MSE: 39241.69980504438
# RMSE: 198.09517865168849
# R2: 0.35197898394760274
# Adjusted R2: 0.35167091873880174
# c3
# MSE: 37939.910138725754
# RMSE: 194.78169867501862
# R2: 0.3734761939676914
# Adjusted R2: 0.37317834840042896
# c4
# MSE: 37939.910138725754
# RMSE: 194.78169867501862
# R2: 0.3734761939676914
# Adjusted R2: 0.37317834840042896
# c5
# c6
# RF
# MSE: 40223.856052857715
# RMSE: 200.5588593227876
# R2: 0.33755938637443195
# Adjusted R2: 0.33692924262223234
# DT
# MSE: 41136.37945127762
# RMSE: 202.82105278120815
# R2: 0.3225311762693983
# Adjusted R2: 0.32188673699770665
# BR
# MSE: 40460.51147455288
# RMSE: 201.14798401811757
# R2: 0.33366194395718707
# Adjusted R2: 0.33302809277984136
# BR
# Binning 0.426 GB of training data: 1.825 s
# Binning 0.047 GB of validation data: 0.079 s
# Fitting gradient boosted rounds:
# [1/100] 1 tree, 31 leaves, max depth =
100] 1 tree, 31 leaves, max depth = 10, train loss: 41.32315, val loss: 41.39417, in 0.182s
# [76/100] 1 tree, 31 leaves, max depth = 15, train loss: 41.31164, val loss: 41.38408, in 0.188s
# [77/100] 1 tree, 31 leaves, max depth = 9, train loss: 41.28515, val loss: 41.35480, in 0.167s
# [78/100] 1 tree, 31 leaves, max depth = 14, train loss: 41.27841, val loss: 41.35050, in 0.156s
# [79/100] 1 tree, 31 leaves, max depth = 15, train loss: 41.26865, val loss: 41.34975, in 0.180s
# [80/100] 1 tree, 31 leaves, max depth = 13, train loss: 41.24910, val loss: 41.34292, in 0.190s
# [81/100] 1 tree, 31 leaves, max depth = 15, train loss: 41.23336, val loss: 41.32907, in 0.191s
# [82/100] 1 tree, 31 leaves, max depth = 13, train loss: 41.22529, val loss: 41.32238, in 0.183s
# [83/100] 1 tree, 31 leaves, max depth = 10, train loss: 41.21952, val loss: 41.31861, in 0.201s
# [84/100] 1 tree, 31 leaves, max depth = 16, train loss: 41.21277, val loss: 41.31809, in 0.160s
# [85/100] 1 tree, 31 leaves, max depth = 10, train loss: 41.20404, val loss: 41.31192, in 0.163s
# [86/100] 1 tree, 31 leaves, max depth = 11, train loss: 41.19289, val loss: 41.30287, in 0.184s
# [87/100] 1 tree, 31 leaves, max depth = 10, train loss: 41.18757, val loss: 41.30346, in 0.155s
# [88/100] 1 tree, 31 leaves, max depth = 9, train loss: 41.18196, val loss: 41.30169, in 0.171s
# [89/100] 1 tree, 31 leaves, max depth = 12, train loss: 41.17068, val loss: 41.28917, in 0.166s
# [90/100] 1 tree, 31 leaves, max depth = 9, train loss: 41.16492, val loss: 41.28950, in 0.159s
# [91/100] 1 tree, 31 leaves, max depth = 10, train loss: 41.15761, val loss: 41.28713, in 0.163s
# [92/100] 1 tree, 31 leaves, max depth = 10, train loss: 41.15195, val loss: 41.28144, in 0.170s
# [93/100] 1 tree, 31 leaves, max depth = 8, train loss: 41.14750, val loss: 41.27768, in 0.171s
# [94/100] 1 tree, 31 leaves, max depth = 8, train loss: 41.13946, val loss: 41.26990, in 0.169s
# [95/100] 1 tree, 31 leaves, max depth = 10, train loss: 41.13388, val loss: 41.26557, in 0.169s
# [96/100] 1 tree, 31 leaves, max depth = 11, train loss: 41.12104, val loss: 41.25849, in 0.157s
# [97/100] 1 tree, 31 leaves, max depth = 11, train loss: 41.11161, val loss: 41.25632, in 0.203s
# [98/100] 1 tree, 31 leaves, max depth = 13, train loss: 41.07620, val loss: 41.22028, in 0.428s
# [99/100] 1 tree, 31 leaves, max depth = 12, train loss: 41.02241, val loss: 41.19483, in 0.591s
# [100/100] 1 tree, 31 leaves, max depth = 12, train loss: 40.96905, val loss: 41.16530, in 0.185s
# Fit 100 trees in 24.259 s, (3100 total leaves)
# Time spent computing histograms: 6.356s
# Time spent finding best splits:  0.218s
# Time spent applying splits:      0.962s
# Time spent predicting:           0.258s
# MSE: 39118.531972724006
# RMSE: 197.78405388889166
# R2: 0.35576280180374087
# Adjusted R2: 0.35514997397128645
# c1
# MSE: 40223.106139097355
# RMSE: 200.55698975377885
# R2: 0.3375717365909533
# Adjusted R2: 0.3369416045868435
# c2
# MSE: 40179.185942833814
# RMSE: 200.44746429634327
# R2: 0.33829505167355356
# Adjusted R2: 0.3376656077197697
# c3
# MSE: 38957.492534668585
# RMSE: 197.37652478111116
# R2: 0.3584149360005011
# Adjusted R2: 0.35780463099916504
# c4
# MSE: 38957.492534668585
# RMSE: 197.37652478111116
# R2: 0.3584149360005011
# Adjusted R2: 0.35780463099916504
# c5
# c6
# RF
# MSE: 38381.885419522376
# RMSE: 195.91295367974618
# R2: 0.33522869886143003
# Adjusted R2: 0.3339627730378806
# DT
# MSE: 39232.043317504154
# RMSE: 198.0708037988036
# R2: 0.32050402950667456
# Adjusted R2: 0.3192100634546322
# BR
# MSE: 38417.89184412034
# RMSE: 196.00482607354428
# R2: 0.334605070358877
# Adjusted R2: 0.33333795695784885
# BR
# Binning 0.449 GB of training data: 1.861 s
# Binning 0.050 GB of validation data: 0.081 s
# Fitting gradient boosted rounds:
# [1/100] 1 tree, 31 leaves, max depth =
# [31/100] 1 tree, 31 leaves, max depth = 13, train loss: 42.53142, val loss: 43.65314, in 0.190s
# [32/100] 1 tree, 31 leaves, max depth = 11, train loss: 42.49238, val loss: 43.60953, in 0.218s
# [33/100] 1 tree, 31 leaves, max depth = 11, train loss: 42.45815, val loss: 43.57751, in 0.230s
# [34/100] 1 tree, 31 leaves, max depth = 12, train loss: 42.42733, val loss: 43.56189, in 0.210s
# [35/100] 1 tree, 31 leaves, max depth = 12, train loss: 42.39083, val loss: 43.52901, in 0.178s
# [36/100] 1 tree, 31 leaves, max depth = 9, train loss: 42.34221, val loss: 43.49078, in 0.220s
# [37/100] 1 tree, 31 leaves, max depth = 16, train loss: 42.31143, val loss: 43.45881, in 0.238s
# [38/100] 1 tree, 31 leaves, max depth = 11, train loss: 42.27179, val loss: 43.42852, in 0.227s
# [39/100] 1 tree, 31 leaves, max depth = 12, train loss: 42.19553, val loss: 43.38454, in 0.215s
# [40/100] 1 tree, 31 leaves, max depth = 10, train loss: 42.16889, val loss: 43.36670, in 0.514s
# [41/100] 1 tree, 31 leaves, max depth = 15, train loss: 42.13064, val loss: 43.33256, in 0.547s
# [42/100] 1 tree, 31 leaves, max depth = 12, train loss: 42.06997, val loss: 43.29181, in 0.259s
# [43/100] 1 tree, 31 leaves, max depth = 17, train loss: 42.04528, val loss: 43.27810, in 0.210s
# [44/100] 1 tree, 31 leaves, max depth = 14, train loss: 42.01240, val loss: 43.27479, in 0.174s
# [45/100] 1 tree, 31 leaves, max depth = 8, train loss: 41.97871, val loss: 43.24976, in 0.202s
# [46/100] 1 tree, 31 leaves, max depth = 11, train loss: 41.95030, val loss: 43.22055, in 0.197s
# [47/100] 1 tree, 31 leaves, max depth = 11, train loss: 41.92720, val loss: 43.19764, in 0.251s
# [48/100] 1 tree, 31 leaves, max depth = 12, train loss: 41.90984, val loss: 43.18223, in 0.295s
# [49/100] 1 tree, 31 leaves, max depth = 11, train loss: 41.88650, val loss: 43.18136, in 0.190s
# [50/100] 1 tree, 31 leaves, max depth = 10, train loss: 41.86414, val loss: 43.16374, in 0.183s
# [51/100] 1 tree, 31 leaves, max depth = 12, train loss: 41.83624, val loss: 43.14397, in 0.209s
# [52/100] 1 tree, 31 leaves, max depth = 10, train loss: 41.82244, val loss: 43.13284, in 0.179s
# [53/100] 1 tree, 31 leaves, max depth = 12, train loss: 41.80623, val loss: 43.12899, in 0.223s
# [54/100] 1 tree, 31 leaves, max depth = 11, train loss: 41.77663, val loss: 43.11174, in 0.219s
# [55/100] 1 tree, 31 leaves, max depth = 10, train loss: 41.75828, val loss: 43.10101, in 0.220s
# [56/100] 1 tree, 31 leaves, max depth = 15, train loss: 41.74100, val loss: 43.09153, in 0.191s
# [57/100] 1 tree, 31 leaves, max depth = 11, train loss: 41.72864, val loss: 43.08136, in 0.199s
# [58/100] 1 tree, 31 leaves, max depth = 9, train loss: 41.71624, val loss: 43.07385, in 0.206s
# [59/100] 1 tree, 31 leaves, max depth = 12, train loss: 41.67456, val loss: 43.04561, in 0.173s
# [60/100] 1 tree, 31 leaves, max depth = 15, train loss: 41.64455, val loss: 43.02746, in 0.167s
# [61/100] 1 tree, 31 leaves, max depth = 10, train loss: 41.62506, val loss: 43.01710, in 0.231s
# [62/100] 1 tree, 31 leaves, max depth = 10, train loss: 41.61262, val loss: 43.00710, in 0.192s
# [63/100] 1 tree, 31 leaves, max depth = 11, train loss: 41.59864, val loss: 43.00151, in 0.219s
# [64/100] 1 tree, 31 leaves, max depth = 11, train loss: 41.53110, val loss: 42.98244, in 0.190s
# [65/100] 1 tree, 31 leaves, max depth = 9, train loss: 41.50674, val loss: 42.96455, in 0.172s
# [66/100] 1 tree, 31 leaves, max depth = 9, train loss: 41.48958, val loss: 42.95198, in 0.231s
# [67/100] 1 tree, 31 leaves, max depth = 14, train loss: 41.46733, val loss: 42.93027, in 0.180s
# [68/100] 1 tree, 31 leaves, max depth = 9, train loss: 41.44015, val loss: 42.92371, in 0.227s
# [69/100] 1 tree, 31 leaves, max depth = 8, train loss: 41.43037, val loss: 42.91436, in 0.182s
# [70/100] 1 tree, 31 leaves, max depth = 9, train loss: 41.42304, val loss: 42.90788, in 0.175s
# [71/100] 1 tree, 31 leaves, max depth = 10, train loss: 41.41540, val loss: 42.90155, in 0.186s
# [72/100] 1 tree, 31 leaves, max depth = 9, train loss: 41.40329, val loss: 42.89216, in 0.188s
# [73/100] 1 tree, 31 leaves, max depth = 9, train loss: 41.39644, val loss: 42.89234, in 0.184s
# [74/100] 1 tree, 31 leaves, max depth = 10, train loss: 41.38194, val loss: 42.87736, in 0.174s
# [75/100] 1 tree, 31 leaves, max depth = 16, train loss: 41.37313, val loss: 42.87416, in 0.169s
# [76/100] 1 tree, 31 leaves, max depth = 13, train loss: 41.36717, val loss: 42.87272, in 0.172s
# [77/100] 1 tree, 31 leaves, max depth = 12, train loss: 41.35281, val loss: 42.86777, in 0.181s
# [78/100] 1 tree, 31 leaves, max depth = 14, train loss: 41.33377, val loss: 42.84851, in 0.211s
# [79/100] 1 tree, 31 leaves, max depth = 11, train loss: 41.31949, val loss: 42.85106, in 0.172s
# [80/100] 1 tree, 31 leaves, max depth = 10, train loss: 41.29094, val loss: 42.83333, in 0.196s
# [81/100] 1 tree, 31 leaves, max depth = 12, train loss: 41.26925, val loss: 42.81413, in 0.172s
# [82/100] 1 tree, 31 leaves, max depth = 10, train loss: 41.25846, val loss: 42.80957, in 0.160s
# [83/100] 1 tree, 31 leaves, max depth = 9, train loss: 41.24563, val loss: 42.79881, in 0.169s
# [84/100] 1 tree, 31 leaves, max depth = 10, train loss: 41.22781, val loss: 42.79119, in 0.175s
# [85/100] 1 tree, 31 leaves, max depth = 18, train loss: 41.22155, val loss: 42.78695, in 0.163s
# [86/100] 1 tree, 31 leaves, max depth = 10, train loss: 41.21086, val loss: 42.77892, in 0.167s
# [87/100] 1 tree, 31 leaves, max depth = 10, train loss: 41.17433, val loss: 42.76394, in 0.222s
# [88/100] 1 tree, 31 leaves, max depth = 12, train loss: 41.15747, val loss: 42.74850, in 0.165s
# [89/100] 1 tree, 31 leaves, max depth = 12, train loss: 41.13948, val loss: 42.73828, in 0.193s
# [90/100] 1 tree, 31 leaves, max depth = 10, train loss: 41.13158, val loss: 42.73393, in 0.194s
# [91/100] 1 tree, 31 leaves, max depth = 12, train loss: 41.12554, val loss: 42.72898, in 0.165s
# [92/100] 1 tree, 31 leaves, max depth = 10, train loss: 41.11627, val loss: 42.72844, in 0.179s
# [93/100] 1 tree, 31 leaves, max depth = 12, train loss: 41.11059, val loss: 42.72235, in 0.172s
# [94/100] 1 tree, 31 leaves, max depth = 11, train loss: 41.09372, val loss: 42.70694, in 0.191s
# [95/100] 1 tree, 31 leaves, max depth = 11, train loss: 41.08218, val loss: 42.69909, in 0.187s
# [96/100] 1 tree, 31 leaves, max depth = 12, train loss: 41.07753, val loss: 42.69856, in 0.179s
# [97/100] 1 tree, 31 leaves, max depth = 9, train loss: 41.07334, val loss: 42.69556, in 0.182s
# [98/100] 1 tree, 31 leaves, max depth = 12, train loss: 41.06262, val loss: 42.68970, in 0.170s
# [99/100] 1 tree, 31 leaves, max depth = 10, train loss: 41.05129, val loss: 42.68453, in 0.167s
# [100/100] 1 tree, 31 leaves, max depth = 11, train loss: 41.04022, val loss: 42.67492, in 0.201s
# Fit 100 trees in 24.871 s, (3100 total leaves)
# Time spent computing histograms: 6.565s
# Time spent finding best splits:  0.166s
# Time spent applying splits:      0.933s
# Time spent predicting:           0.264s
# MSE: 37175.716120009245
# RMSE: 192.81005191641137
# R2: 0.3561194582878261
# Adjusted R2: 0.35489331479511155
# c1
# MSE: 38343.53603640275
# RMSE: 195.81505569389384
# R2: 0.3358929072252361
# Adjusted R2: 0.33462824625550713
# c2
# MSE: 38229.48699364292
# RMSE: 195.52362259748287
# R2: 0.3378682278672622
# Adjusted R2: 0.33660732850608377
# c3
# MSE: 37062.780012794916
# RMSE: 192.51696032504492
# R2: 0.35807550297186885
# Adjusted R2: 0.35685308438044483
# c4
# MSE: 37061.67558268756
# RMSE: 192.5140919067681
# R2: 0.35809463161631816
# Adjusted R2: 0.35687224945162455
# c5
# c6
# end

# %%
df=pd.DataFrame([pd.Series(mn),pd.Series(Tr),pd.Series(te),pd.Series(r2_value),pd.Series(adj_r2_value),pd.Series(RMSE_value),
                pd.Series(max_i_),pd.Series(max_j_),pd.Series(max_k_),pd.Series(max_l_),pd.Series(times)], 
                index = ["Model Name","Train size","Test size","r2","Adjusted r2","RMSE",
                         "RF weight","DT weight","BR weight value","GBR weight","Time"])
df.head()
# Out:
#                                   0                        1   \
# Model Name   RandomForestRegressor()  DecisionTreeRegressor()
# Train size                       0.7                      0.7
# Test size                        0.3                      0.3
# r2                          0.358345                 0.340997
# Adjusted r2                 0.358142                 0.340788
#
#                              2                            3           4   \
# Model Name   BaggingRegressor()  GradientBoostingRegressor()  weight 1()
# Train size                  0.7                          0.7         0.7
# Test size                   0.3                          0.3         0.3
# r2                     0.351828                      0.37815    0.358345
# Adjusted r2            0.351623                     0.377953    0.358142
#
#                      5           6           7                        8   \
# Model Name   weight 2()  weight 3()  weight 4()  RandomForestRegressor()
# Train size          0.7         0.7         0.7                      0.8
# Test size           0.3         0.3         0.3                      0.2
# r2             0.359115    0.380679    0.380734                 0.350036
# Adjusted r2    0.358912    0.380483    0.380537                 0.349727
#
#                                   9   ...          22          23  \
# Model Name   DecisionTreeRegressor()  ...  weight 3()  weight 4()
# Train size                       0.8  ...         0.9         0.9
# Test size                        0.2  ...         0.1         0.1
# r2                          0.336134  ...    0.358415    0.358415
# Adjusted r2                 0.335819  ...    0.357805    0.357805
#
#                                   24                       25  \
# Model Name   RandomForestRegressor()  DecisionTreeRegressor()
# Train size                      0.95                     0.95
# Test size                       0.05                     0.05
# r2                          0.335229                 0.320504
# Adjusted r2                 0.333963                  0.31921
#
#                              26                           27          28  \
# Model Name   BaggingRegressor()  GradientBoostingRegressor()  weight 1()
# Train size                 0.95                         0.95        0.95
# Test size                  0.05                         0.05        0.05
# r2                     0.334605                     0.356119    0.335893
# Adjusted r2            0.333338                     0.354893    0.334628
#
#                      29          30          31
# Model Name   weight 2()  weight 3()  weight 4()
# Train size         0.95        0.95        0.95
# Test size          0.05        0.05        0.05
# r2             0.337868    0.358076    0.358095
# Adjusted r2    0.336607    0.356853    0.356872
#
# [5 rows x 32 columns]

# %%
df1=df.T
df1.head()
# Out:
#                     Model Name Train size Test size        r2 Adjusted r2  \
# 0      RandomForestRegressor()        0.7       0.3  0.358345    0.358142
# 1      DecisionTreeRegressor()        0.7       0.3  0.340997    0.340788
# 2           BaggingRegressor()        0.7       0.3  0.351828    0.351623
# 3  GradientBoostingRegressor()        0.7       0.3   0.37815    0.377953
# 4                   weight 1()        0.7       0.3  0.358345    0.358142
#
#          RMSE RF weight DT weight BR weight value GBR weight        Time
# 0  194.906848         0         0               0          0  559.476681
# 1  197.524137         0         0               0          0    8.926332
# 2  195.894151         0         0               0          0   62.403033
# 3  191.875352         0         0               0          0   19.942588
# 4  194.906848       100         0               0          0         0.0

# %%
df1.to_csv("Table.csv")

# %%
df1
# Out:
#                      Model Name Train size Test size        r2 Adjusted r2  \
# 0       RandomForestRegressor()        0.7       0.3  0.358345    0.358142
# 1       DecisionTreeRegressor()        0.7       0.3  0.340997    0.340788
# 2            BaggingRegressor()        0.7       0.3  0.351828    0.351623
# 3   GradientBoostingRegressor()        0.7       0.3   0.37815    0.377953
# 4                    weight 1()        0.7       0.3  0.358345    0.358142
# 5                    weight 2()        0.7       0.3  0.359115    0.358912
# 6                    weight 3()        0.7       0.3  0.380679    0.380483
# 7                    weight 4()        0.7       0.3  0.380734    0.380537
# 8       RandomForestRegressor()        0.8       0.2  0.350036    0.349727
# 9       DecisionTreeRegressor()        0.8       0.2  0.336134    0.335819
# 10           BaggingRegressor()        0.8       0.2  0.350193    0.349884
# 11  GradientBoostingRegressor()        0.8       0.2  0.371076    0.370777
# 12                   weight 1()        0.8       0.2  0.351381    0.351072
# 13                   weight 2()        0.8       0.2  0.351979    0.351671
# 14                   weight 3()        0.8       0.2  0.373476    0.373178
# 15                   weight 4()        0.8       0.2  0.373476    0.373178
# 16      RandomForestRegressor()        0.9       0.1  0.337559    0.336929
# 17      DecisionTreeRegressor()        0.9       0.1  0.322531    0.321887
# 18           BaggingRegressor()        0.9       0.1  0.333662    0.333028
# 19  GradientBoostingRegressor()        0.9       0.1  0.355763     0.35515
# 20                   weight 1()        0.9       0.1  0.337572    0.336942
# 21                   weight 2()        0.9       0.1  0.338295    0.337666
# 22                   weight 3()        0.9       0.1  0.358415    0.357805
# 23                   weight 4()        0.9       0.1  0.358415    0.357805
# 24      RandomForestRegressor()       0.95      0.05  0.335229    0.333963
# 25      DecisionTreeRegressor()       0.95      0.05  0.320504     0.31921
# 26           BaggingRegressor()       0.95      0.05  0.334605    0.333338
# 27  GradientBoostingRegressor()       0.95      0.05  0.356119    0.354893
# 28                   weight 1()       0.95      0.05  0.335893    0.334628
# 29                   weight 2()       0.95      0.05  0.337868    0.336607
# 30                   weight 3()       0.95      0.05  0.358076    0.356853
# 31                   weight 4()       0.95      0.05  0.358095    0.356872
#
#           RMSE RF weight DT weight BR weight value GBR weight        Time
# 0   194.906848         0         0               0          0  559.476681
# 1   197.524137         0         0               0          0    8.926332
# 2   195.894151         0         0               0          0   62.403033
# 3   191.875352         0         0               0          0   19.942588
# 4   194.906848       100         0               0          0         0.0
# 5   194.789966       135       -25             -10          0         0.0
# 6   191.484833        25         0               0         75         0.0
# 7   191.476344        35         0             -10         75         0.0
# 8   198.391866         0         0               0          0  661.176472
# 9   200.502359         0         0               0          0    10.71984
# 10  198.368023         0         0               0          0   72.555686
# 11  195.154382         0         0               0          0   22.203737
# 12  198.186606        48         0              52          0         0.0
# 13  198.095179        70       -25              55          0         0.0
# 14  194.781699         3         0              22         75         0.0
# 15  194.781699         3         0              22         75         0.0
# 16  200.558859         0         0               0          0  756.893783
# 17  202.821053         0         0               0          0   12.920727
# 18  201.147984         0         0               0          0   86.079849
# 19  197.784054         0         0               0          0   24.262442
# 20   200.55699        95         0               5          0         0.0
# 21  200.447464       116       -27              11          0         0.0
# 22  197.376525        20         0               6         74         0.0
# 23  197.376525        20         0               6         74         0.0
# 24  195.912954         0         0               0          0  796.651448
# 25  198.070804         0         0               0          0   12.797468
# 26  196.004826         0         0               0          0   95.799308
# 27  192.810052         0         0               0          0   24.873753
# 28  195.815056        58         0              42          0         0.0
# 29  195.523623       110       -52              42          0         0.0
# 30   192.51696         0         0              22         78         0.0
# 31  192.514092        -7         0              29         78         0.0
