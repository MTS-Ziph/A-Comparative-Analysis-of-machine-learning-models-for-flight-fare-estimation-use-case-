# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("../input/easemytrip-flight-fare-travel-listings/marketing_sample_for_easemytrip_in-easemytrip_flights_fares__20200401_20200630__30k_data.csv")
df
# Out:
#                                 Uniq Id            Crawl Timestamp     Source  \
# 0      53f192419756cfa95baa4745067354f5  2020-04-01 01:23:42 +0000      Delhi
# 1      7bb845050e88cc6a4f17abf24794c73b  2020-04-01 00:59:51 +0000     Mumbai
# 2      c9a84cc24d8a350eb41555c7bb76def6  2020-04-01 00:56:35 +0000  Ahmedabad
# 3      0c0a87ac2229b8c3f1b322baf1fc9f4e  2020-04-01 00:42:35 +0000    Kolkata
# 4      b8f8af12fd6d9bf2f24389f26488478c  2020-04-01 01:52:13 +0000     Indore
# ...                                 ...                        ...        ...
# 29995  35c0bbbb50478edb124b6987ae54864a  2020-04-01 01:50:52 +0000     Ranchi
# 29996  80c354a117f6abea283fd44dd25a95d6  2020-04-01 01:11:27 +0000  Ahmedabad
# 29997  e26c8fd1922e77256b458da1c5895074  2020-04-01 00:57:21 +0000     Mumbai
# 29998  6a81ee6ea557a970dab4499550f27a6c  2020-04-01 01:46:12 +0000     Bhopal
# 29999  29610e1ac73f6b2bbf2827ba3d8f8f33  2020-04-01 01:14:48 +0000      Delhi
#
# ...

# %%
df.columns
# Out:
# Index(['Uniq Id', 'Crawl Timestamp', 'Source', 'Layover1', 'Layover2',
#        'Layover3', 'Destination', 'Flight Operator', 'Flight Number',
#        'Departure Date', 'Departure Time', 'Arrival Date', 'Arrival Time',
#        'Total Time', 'Number Of Stops', 'Fare'],
#       dtype='object')

# %%
df=df.drop(['Uniq Id','Flight Number'],axis=1)

# %%
df.columns
# Out:
# Index(['Crawl Timestamp', 'Source', 'Layover1', 'Layover2', 'Layover3',
#        'Destination', 'Flight Operator', 'Departure Date', 'Departure Time',
#        'Arrival Date', 'Arrival Time', 'Total Time', 'Number Of Stops',
#        'Fare'],
#       dtype='object')

# %%
df[df['Number Of Stops']==1].shape
# Out:
# (16238, 14)

# %%
df1=df[np.logical_or(df['Number Of Stops']==1 , df['Number Of Stops']==0)]

# %%
df1
# Out:
#                  Crawl Timestamp     Source Layover1 Layover2 Layover3  \
# 0      2020-04-01 01:23:42 +0000      Delhi    Patna      NaN      NaN
# 3      2020-04-01 00:42:35 +0000    Kolkata    Delhi      NaN      NaN
# 4      2020-04-01 01:52:13 +0000     Indore   Mumbai      NaN      NaN
# 7      2020-04-01 01:20:18 +0000      Kochi   Mumbai      NaN      NaN
# 8      2020-04-01 01:10:52 +0000   Vadodara    Delhi      NaN      NaN
# ...                          ...        ...      ...      ...      ...
# 29994  2020-04-01 02:16:24 +0000   Abudhabi  Colombo      NaN      NaN
# 29995  2020-04-01 01:50:52 +0000     Ranchi    Delhi      NaN      NaN
# 29996  2020-04-01 01:11:27 +0000  Ahmedabad     Pune      NaN      NaN
# 29997  2020-04-01 00:57:21 +0000     Mumbai    Delhi      NaN      NaN
# 29999  2020-04-01 01:14:48 +0000      Delhi      NaN      NaN      NaN
#
#       Destination                        Flight Operator Departure Date  \
# ...

# %%
df1['Flight Operator'].unique()
# Out:
# array(['SpiceJet|SpiceJet', 'Indigo|Indigo', 'Air India|Air India',
#        'GoAir', 'British Airways|British Airways', 'AirAsia', 'Indigo',
#        'Vistara|Vistara', 'AirAsia|AirAsia', 'GoAir|GoAir',
#        'Etihad Airways|Etihad Airways',
#        'National Air Services|National Air Services', 'SpiceJet',
#        'Qatar Airways|Qatar Airways', 'AirArabia|AirArabia', 'Vistara',
#        'Lufthansa Airways|Air India', 'Virgin Atlantic Airways|Air India',
#        'Turkish Airlines|Turkish Airlines',
#        'LOT Polish Airlines|LOT Polish Airlines',
#        'SriLankan Airlines|SriLankan Airlines', 'Air India',
#        'Nepal Airways', 'Gulf Airways|Gulf Airways',
#        'Ethiopian Airlines|Ethiopian Airlines',
#        'Saudi Arabian Airlines|Saudi Arabian Airlines', 'Etihad Airways',
#        'EVA Airways|China Eastern Airlines', 'SriLankan Airlines',
#        'Virgin Atlantic Airways|Virgin Atlantic Airways', 'Trujet',
# ...

# %%
df1['Flight Operator']=df1['Flight Operator']+'|'
val=df1['Flight Operator'].str.split("|")
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
val
# Out:
# 0                            [SpiceJet, SpiceJet, ]
# 3                            [SpiceJet, SpiceJet, ]
# 4                                [Indigo, Indigo, ]
# 7                            [SpiceJet, SpiceJet, ]
# 8                          [Air India, Air India, ]
#                             ...
# 29994    [SriLankan Airlines, SriLankan Airlines, ]
# 29995                            [Indigo, Indigo, ]
# 29996                        [SpiceJet, SpiceJet, ]
# 29997                          [Vistara, Vistara, ]
# 29999                                     [GoAir, ]
# Name: Flight Operator, Length: 17848, dtype: object

# %%
v1=[]
v2=[]
for i in val:
    v1.append(i[0])
    v2.append(i[1])

# %%
df1['F1']=v1
df1['F2']=v2
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df1.columns
# Out:
# Index(['Crawl Timestamp', 'Source', 'Layover1', 'Layover2', 'Layover3',
#        'Destination', 'Flight Operator', 'Departure Date', 'Departure Time',
#        'Arrival Date', 'Arrival Time', 'Total Time', 'Number Of Stops', 'Fare',
#        'F1', 'F2'],
#       dtype='object')

# %%
df1.shape
# Out:
# (17848, 16)

# %%
df1=df1[np.logical_or(df1['Number Of Stops']==0,np.logical_and(df1['Number Of Stops']==1,df1['F1']==df1['F2']))]

# %%
df1
# Out:
#                  Crawl Timestamp     Source Layover1 Layover2 Layover3  \
# 0      2020-04-01 01:23:42 +0000      Delhi    Patna      NaN      NaN
# 3      2020-04-01 00:42:35 +0000    Kolkata    Delhi      NaN      NaN
# 4      2020-04-01 01:52:13 +0000     Indore   Mumbai      NaN      NaN
# 7      2020-04-01 01:20:18 +0000      Kochi   Mumbai      NaN      NaN
# 8      2020-04-01 01:10:52 +0000   Vadodara    Delhi      NaN      NaN
# ...                          ...        ...      ...      ...      ...
# 29994  2020-04-01 02:16:24 +0000   Abudhabi  Colombo      NaN      NaN
# 29995  2020-04-01 01:50:52 +0000     Ranchi    Delhi      NaN      NaN
# 29996  2020-04-01 01:11:27 +0000  Ahmedabad     Pune      NaN      NaN
# 29997  2020-04-01 00:57:21 +0000     Mumbai    Delhi      NaN      NaN
# 29999  2020-04-01 01:14:48 +0000      Delhi      NaN      NaN      NaN
#
#       Destination                         Flight Operator Departure Date  \
# ...

# %%
df1['F1'].unique()
# Out:
# array(['SpiceJet', 'Indigo', 'Air India', 'GoAir', 'British Airways',
#        'AirAsia', 'Vistara', 'Etihad Airways', 'National Air Services',
#        'Qatar Airways', 'AirArabia', 'Turkish Airlines',
#        'LOT Polish Airlines', 'SriLankan Airlines', 'Nepal Airways',
#        'Gulf Airways', 'Ethiopian Airlines', 'Saudi Arabian Airlines',
#        'Virgin Atlantic Airways', 'Trujet', 'Delta Airlines',
#        'American Airlines', 'All Nippon Airways', 'Kenya Airways',
#        'Singapore Airlines', 'Biman Bangladesh', 'Air India Express',
#        'FlyDubai', 'Ukraine Intl Airlines', 'Oman Air',
#        'Lufthansa Airways', 'China Eastern Airlines', 'Air Canada',
#        'Jazeera Airways', 'Myanmar Airways Intl'], dtype=object)

# %%
df1=df1.drop(['Layover2', 'Layover3','Flight Operator','F2'],axis=1)

# %%
df1
# Out:
#                  Crawl Timestamp     Source Layover1 Destination  \
# 0      2020-04-01 01:23:42 +0000      Delhi    Patna    Guwahati
# 3      2020-04-01 00:42:35 +0000    Kolkata    Delhi       Kochi
# 4      2020-04-01 01:52:13 +0000     Indore   Mumbai     Chennai
# 7      2020-04-01 01:20:18 +0000      Kochi   Mumbai       Delhi
# 8      2020-04-01 01:10:52 +0000   Vadodara    Delhi      Mumbai
# ...                          ...        ...      ...         ...
# 29994  2020-04-01 02:16:24 +0000   Abudhabi  Colombo     Chennai
# 29995  2020-04-01 01:50:52 +0000     Ranchi    Delhi     Chennai
# 29996  2020-04-01 01:11:27 +0000  Ahmedabad     Pune   Bengaluru
# 29997  2020-04-01 00:57:21 +0000     Mumbai    Delhi      Ranchi
# 29999  2020-04-01 01:14:48 +0000      Delhi      NaN   Hyderabad
#
#       Departure Date Departure Time Arrival Date Arrival Time Total Time  \
# 0          23Apr2020          13:10    23Apr2020        22:00    08h 50m
# ...

# %%
df1.dtypes
# Out:
# Crawl Timestamp     object
# Source              object
# Layover1            object
# Destination         object
# Departure Date      object
# Departure Time      object
# Arrival Date        object
# Arrival Time        object
# Total Time          object
# Number Of Stops      int64
# Fare               float64
# F1                  object
# dtype: object

# %%
from datetime import datetime

# %%
df1.head()
# Out:
#              Crawl Timestamp    Source Layover1 Destination Departure Date  \
# 0  2020-04-01 01:23:42 +0000     Delhi    Patna    Guwahati      23Apr2020
# 3  2020-04-01 00:42:35 +0000   Kolkata    Delhi       Kochi      16Apr2020
# 4  2020-04-01 01:52:13 +0000    Indore   Mumbai     Chennai      18Apr2020
# 7  2020-04-01 01:20:18 +0000     Kochi   Mumbai       Delhi      27Apr2020
# 8  2020-04-01 01:10:52 +0000  Vadodara    Delhi      Mumbai      18Apr2020
#
#   Departure Time Arrival Date Arrival Time Total Time  Number Of Stops  \
# 0          13:10    23Apr2020        22:00    08h 50m                1
# 3          18:00    17Apr2020        11:10    17h 10m                1
# 4          07:25    18Apr2020        13:35    06h 10m                1
# 7          05:35    27Apr2020        15:40    10h 05m                1
# 8          20:20    19Apr2020        12:50    16h 30m                1
#
#      Fare         F1
# 0  4378.0   SpiceJet
# 3  5226.0   SpiceJet
# ...

# %%
df1['Crawl Timestamp']=pd.to_datetime(df1['Crawl Timestamp'])

# %%
df1.head()
# Out:
#             Crawl Timestamp    Source Layover1 Destination Departure Date  \
# 0 2020-04-01 01:23:42+00:00     Delhi    Patna    Guwahati      23Apr2020
# 3 2020-04-01 00:42:35+00:00   Kolkata    Delhi       Kochi      16Apr2020
# 4 2020-04-01 01:52:13+00:00    Indore   Mumbai     Chennai      18Apr2020
# 7 2020-04-01 01:20:18+00:00     Kochi   Mumbai       Delhi      27Apr2020
# 8 2020-04-01 01:10:52+00:00  Vadodara    Delhi      Mumbai      18Apr2020
#
#   Departure Time Arrival Date Arrival Time Total Time  Number Of Stops  \
# 0          13:10    23Apr2020        22:00    08h 50m                1
# 3          18:00    17Apr2020        11:10    17h 10m                1
# 4          07:25    18Apr2020        13:35    06h 10m                1
# 7          05:35    27Apr2020        15:40    10h 05m                1
# 8          20:20    19Apr2020        12:50    16h 30m                1
#
#      Fare         F1
# 0  4378.0   SpiceJet
# 3  5226.0   SpiceJet
# 4  3333.0     Indigo
# ...

# %%
df1.dtypes
# Out:
# Crawl Timestamp    datetime64[ns, UTC]
# Source                          object
# Layover1                        object
# Destination                     object
# Departure Date                  object
# Departure Time                  object
# Arrival Date                    object
# Arrival Time                    object
# Total Time                      object
# Number Of Stops                  int64
# Fare                           float64
# F1                              object
# dtype: object

# %%
df1['Departure']=df1['Departure Date']+" "+df1['Departure Time']

# %%
df1['Departure']=pd.to_datetime(df1['Departure'])
df1.dtypes
# Out:
# Crawl Timestamp    datetime64[ns, UTC]
# Source                          object
# Layover1                        object
# Destination                     object
# Departure Date                  object
# Departure Time                  object
# Arrival Date                    object
# Arrival Time                    object
# Total Time                      object
# Number Of Stops                  int64
# Fare                           float64
# F1                              object
# Departure               datetime64[ns]
# dtype: object

# %%
df1.head()
# Out:
#             Crawl Timestamp    Source Layover1 Destination Departure Date  \
# 0 2020-04-01 01:23:42+00:00     Delhi    Patna    Guwahati      23Apr2020
# 3 2020-04-01 00:42:35+00:00   Kolkata    Delhi       Kochi      16Apr2020
# 4 2020-04-01 01:52:13+00:00    Indore   Mumbai     Chennai      18Apr2020
# 7 2020-04-01 01:20:18+00:00     Kochi   Mumbai       Delhi      27Apr2020
# 8 2020-04-01 01:10:52+00:00  Vadodara    Delhi      Mumbai      18Apr2020
#
#   Departure Time Arrival Date Arrival Time Total Time  Number Of Stops  \
# 0          13:10    23Apr2020        22:00    08h 50m                1
# 3          18:00    17Apr2020        11:10    17h 10m                1
# 4          07:25    18Apr2020        13:35    06h 10m                1
# 7          05:35    27Apr2020        15:40    10h 05m                1
# 8          20:20    19Apr2020        12:50    16h 30m                1
#
#      Fare         F1           Departure
# 0  4378.0   SpiceJet 2020-04-23 13:10:00
# ...

# %%
df1['Crawl Timestamp']=pd.to_datetime(df1['Crawl Timestamp']).dt.tz_localize(None)

# %%
df1.dtypes
# Out:
# Crawl Timestamp    datetime64[ns]
# Source                     object
# Layover1                   object
# Destination                object
# Departure Date             object
# Departure Time             object
# Arrival Date               object
# Arrival Time               object
# Total Time                 object
# Number Of Stops             int64
# Fare                      float64
# F1                         object
# Departure          datetime64[ns]
# dtype: object

# %%
df1
# Out:
#           Crawl Timestamp     Source Layover1 Destination Departure Date  \
# 0     2020-04-01 01:23:42      Delhi    Patna    Guwahati      23Apr2020
# 3     2020-04-01 00:42:35    Kolkata    Delhi       Kochi      16Apr2020
# 4     2020-04-01 01:52:13     Indore   Mumbai     Chennai      18Apr2020
# 7     2020-04-01 01:20:18      Kochi   Mumbai       Delhi      27Apr2020
# 8     2020-04-01 01:10:52   Vadodara    Delhi      Mumbai      18Apr2020
# ...                   ...        ...      ...         ...            ...
# 29994 2020-04-01 02:16:24   Abudhabi  Colombo     Chennai      23Apr2020
# 29995 2020-04-01 01:50:52     Ranchi    Delhi     Chennai      18Apr2020
# 29996 2020-04-01 01:11:27  Ahmedabad     Pune   Bengaluru      16Apr2020
# 29997 2020-04-01 00:57:21     Mumbai    Delhi      Ranchi      18Apr2020
# 29999 2020-04-01 01:14:48      Delhi      NaN   Hyderabad      18Apr2020
#
#       Departure Time Arrival Date Arrival Time Total Time  Number Of Stops  \
# ...

# %%
delta = df1['Departure'] - df1['Crawl Timestamp']

# %%
delta
# Out:
# 0       22 days 11:46:18
# 3       15 days 17:17:25
# 4       17 days 05:32:47
# 7       26 days 04:14:42
# 8       17 days 19:09:08
#               ...
# 29994   22 days 20:43:36
# 29995   17 days 12:59:08
# 29996   15 days 02:48:33
# 29997   17 days 07:47:39
# 29999   17 days 19:40:12
# Length: 17340, dtype: timedelta64[ns]

# %%
d=[]
for i in delta:
    d.append(i.days)

# %%
df1['Days Left']=d

# %%
df1
# Out:
#           Crawl Timestamp     Source Layover1 Destination Departure Date  \
# 0     2020-04-01 01:23:42      Delhi    Patna    Guwahati      23Apr2020
# 3     2020-04-01 00:42:35    Kolkata    Delhi       Kochi      16Apr2020
# 4     2020-04-01 01:52:13     Indore   Mumbai     Chennai      18Apr2020
# 7     2020-04-01 01:20:18      Kochi   Mumbai       Delhi      27Apr2020
# 8     2020-04-01 01:10:52   Vadodara    Delhi      Mumbai      18Apr2020
# ...                   ...        ...      ...         ...            ...
# 29994 2020-04-01 02:16:24   Abudhabi  Colombo     Chennai      23Apr2020
# 29995 2020-04-01 01:50:52     Ranchi    Delhi     Chennai      18Apr2020
# 29996 2020-04-01 01:11:27  Ahmedabad     Pune   Bengaluru      16Apr2020
# 29997 2020-04-01 00:57:21     Mumbai    Delhi      Ranchi      18Apr2020
# 29999 2020-04-01 01:14:48      Delhi      NaN   Hyderabad      18Apr2020
#
#       Departure Time Arrival Date Arrival Time Total Time  Number Of Stops  \
# ...

# %%
days1=[]
m1=[]
yrs=[]
hrs=[]
mins=[]
for i in df1['Departure']:
    days1.append(i.day)
    yrs.append(i.year)
    m1.append(i.month)
    hrs.append(i.hour)
    mins.append(i.minute)

# %%
df1["Departure_day"]=days1
df1["Departure_month"]=m1
df1["Departure_year"]=yrs
df1["Departure_hour"]=hrs
df1["Departure_minute"]=mins

# %%
df1
# Out:
#           Crawl Timestamp     Source Layover1 Destination Departure Date  \
# 0     2020-04-01 01:23:42      Delhi    Patna    Guwahati      23Apr2020
# 3     2020-04-01 00:42:35    Kolkata    Delhi       Kochi      16Apr2020
# 4     2020-04-01 01:52:13     Indore   Mumbai     Chennai      18Apr2020
# 7     2020-04-01 01:20:18      Kochi   Mumbai       Delhi      27Apr2020
# 8     2020-04-01 01:10:52   Vadodara    Delhi      Mumbai      18Apr2020
# ...                   ...        ...      ...         ...            ...
# 29994 2020-04-01 02:16:24   Abudhabi  Colombo     Chennai      23Apr2020
# 29995 2020-04-01 01:50:52     Ranchi    Delhi     Chennai      18Apr2020
# 29996 2020-04-01 01:11:27  Ahmedabad     Pune   Bengaluru      16Apr2020
# 29997 2020-04-01 00:57:21     Mumbai    Delhi      Ranchi      18Apr2020
# 29999 2020-04-01 01:14:48      Delhi      NaN   Hyderabad      18Apr2020
#
#       Departure Time Arrival Date Arrival Time Total Time  Number Of Stops  \
# ...

# %%
df1.columns
# Out:
# Index(['Crawl Timestamp', 'Source', 'Layover1', 'Destination',
#        'Departure Date', 'Departure Time', 'Arrival Date', 'Arrival Time',
#        'Total Time', 'Number Of Stops', 'Fare', 'F1', 'Departure', 'Days Left',
#        'Departure_day', 'Departure_month', 'Departure_year', 'Departure_hour',
#        'Departure_minute'],
#       dtype='object')

# %%
df1=df1.drop(['Crawl Timestamp','Departure Date', 'Departure Time', 'Arrival Date', 'Arrival Time',
       'Total Time','Departure'],axis=1)

# %%
df1.columns
# Out:
# Index(['Source', 'Layover1', 'Destination', 'Number Of Stops', 'Fare', 'F1',
#        'Days Left', 'Departure_day', 'Departure_month', 'Departure_year',
#        'Departure_hour', 'Departure_minute'],
#       dtype='object')

# %%
df1
# Out:
#           Source Layover1 Destination  Number Of Stops     Fare  \
# 0          Delhi    Patna    Guwahati                1   4378.0
# 3        Kolkata    Delhi       Kochi                1   5226.0
# 4         Indore   Mumbai     Chennai                1   3333.0
# 7          Kochi   Mumbai       Delhi                1   3563.0
# 8       Vadodara    Delhi      Mumbai                1   5309.0
# ...          ...      ...         ...              ...      ...
# 29994   Abudhabi  Colombo     Chennai                1  35839.0
# 29995     Ranchi    Delhi     Chennai                1   4161.0
# 29996  Ahmedabad     Pune   Bengaluru                1   2145.0
# 29997     Mumbai    Delhi      Ranchi                1   5009.0
# 29999      Delhi      NaN   Hyderabad                0   2351.0
#
#                        F1  Days Left  Departure_day  Departure_month  \
# 0                SpiceJet         22             23                4
# ...

# %%
def encode_and_bind(original_dataframe, feature_to_encode):
    dummies = pd.get_dummies(original_dataframe[[feature_to_encode]])
    res = pd.concat([original_dataframe, dummies], axis=1)
    return(res)

# %%
df1=encode_and_bind(df1,"F1")
df1=encode_and_bind(df1,"Source")
df1=encode_and_bind(df1,"Destination")
df1=encode_and_bind(df1,"Layover1")

# %%
df1
# Out:
#           Source Layover1 Destination  Number Of Stops     Fare  \
# 0          Delhi    Patna    Guwahati                1   4378.0
# 3        Kolkata    Delhi       Kochi                1   5226.0
# 4         Indore   Mumbai     Chennai                1   3333.0
# 7          Kochi   Mumbai       Delhi                1   3563.0
# 8       Vadodara    Delhi      Mumbai                1   5309.0
# ...          ...      ...         ...              ...      ...
# 29994   Abudhabi  Colombo     Chennai                1  35839.0
# 29995     Ranchi    Delhi     Chennai                1   4161.0
# 29996  Ahmedabad     Pune   Bengaluru                1   2145.0
# 29997     Mumbai    Delhi      Ranchi                1   5009.0
# 29999      Delhi      NaN   Hyderabad                0   2351.0
#
#                        F1  Days Left  Departure_day  Departure_month  \
# 0                SpiceJet         22             23                4
# ...

# %%
df1.to_csv("EaseMyTrip-discriptive.csv")

# %%
df1=df1.drop(['Source', 'Layover1', 'Destination','F1'],axis=1)

# %%
df1
# Out:
#        Number Of Stops     Fare  Days Left  Departure_day  Departure_month  \
# 0                    1   4378.0         22             23                4
# 3                    1   5226.0         15             16                4
# 4                    1   3333.0         17             18                4
# 7                    1   3563.0         26             27                4
# 8                    1   5309.0         17             18                4
# ...                ...      ...        ...            ...              ...
# 29994                1  35839.0         22             23                4
# 29995                1   4161.0         17             18                4
# 29996                1   2145.0         15             16                4
# 29997                1   5009.0         17             18                4
# 29999                0   2351.0         17             18                4
#
# ...

# %%
df1.dtypes
# Out:
# Number Of Stops              int64
# Fare                       float64
# Days Left                    int64
# Departure_day                int64
# Departure_month              int64
#                             ...
# Layover1_Vadodara            uint8
# Layover1_Varanasi            uint8
# Layover1_Vijayawada          uint8
# Layover1_Vishakhapatnam      uint8
# Layover1_Warsaw              uint8
# Length: 365, dtype: object

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17340 entries, 0 to 29999
# Columns: 365 entries, Number Of Stops to Layover1_Warsaw
# dtypes: float64(1), int64(7), uint8(357)
# memory usage: 7.1 MB

# %%
df1.isnull().values.any()
# Out:
# False

# %%
df1.to_csv("EaseMyTrip.csv")
